# %%
import matplotlib.pyplot as plt

dtheta_dt =[11,113,212,314,415,516,616,718]
Tensao_cisalhante = [3.9,9.8,13.6,16.8,19.4,22,24,26.3]


def viscosidade(n,du_dy):
    return n*du_dy

def f_gabarito(x):
    return 1,23*dtheta_dt**0.46

#todo linha de ajuste geometrica
plt.scatter(dtheta_dt,Tensao_cisalhante)
