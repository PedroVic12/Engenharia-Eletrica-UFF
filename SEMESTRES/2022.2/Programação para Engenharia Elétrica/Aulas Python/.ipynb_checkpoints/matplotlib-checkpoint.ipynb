# %% [markdown]
# #### 1) Construa uma função em Python que faça um mapeamento linear de valores de uma lista de tamanho n para uma nova lista com os limites a e b. Considere:
#
# a) Execute a função, para mapear uma lista de números interios de 0 a 1023 para uma lista de numeros inteiros de 0 a 255. Imprime as duas listas na tela.

# %% [markdown]
# ## Exemplo de numeros aleatorios

# %%
import random

def numero_inteiro():
    print("Gerando cinco numeros aleatorios entre 1 e 50:")
    for i in range(1,1024):
        numero = random.randint(1,1023)
        print("Numero = ", numero)
# Out:
# Gerando cinco numeros aleatorios entre 1 e 50:
# Numero =  29
# Numero =  4
# Numero =  23
# Numero =  14
# Numero =  24

# %% [markdown]
# ## Exemplo Matplotlib

# %%
import matplotlib.pyplot as grafico

meses = ["Janeiro", "Fevereiro", "Março"," Abril","Maio", "Junho"]

t_media = [30,31,27,26,22,18]

grafico.ylabel("Temperatura / ºC")
grafico.xlabel("Mes")
grafico.plot(meses,t_media)

# %% [markdown]
# # Código Principal
