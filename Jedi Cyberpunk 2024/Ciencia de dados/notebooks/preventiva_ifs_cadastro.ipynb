# %%
class DSA_Analise:

    def __init__(self, lista):
        self.lista = lista

    def maior_elemento(self):
        return max(self.lista)

    def menor_elemento(self):
        return min(self.lista)

    def tamanho_lista(self):
        return len(self.lista)

    def media(self):
        return sum(self.lista) / len(self.lista)

    def mediana(self):
        lista_ordenada = sorted(self.lista)
        tamanho = len(lista_ordenada)
        if tamanho % 2 == 0:
            return (lista_ordenada[tamanho // 2 - 1] + lista_ordenada[tamanho // 2]) / 2
        else:
            return lista_ordenada[tamanho // 2]

    def moda(self):
        contagem = {}
        for i in self.lista:
            if i in contagem:
                contagem[i] += 1
            else:
                contagem[i] = 1
        moda = max(contagem.values())
        return [i for i in contagem if contagem[i] == moda]

    def desvio_padrao(self):
        media = self.media()
        variancia = sum((x - media) ** 2 for x in self.lista) / len(self.lista)
        return variancia ** 0.5

    def coeficiente_variacao(self):
        return self.desvio_padrao() / self.media()

    def amplitude(self):
        return self.maior_elemento() - self.menor_elemento()

    def amplitude_interquartil(self):
        lista_ordenada = sorted(self.lista)
        tamanho = len(lista_ordenada)
        if tamanho % 2 == 0:
            q1 = lista_ordenada[tamanho // 4 - 1]
            q3 = lista_ordenada[tamanho // 4 * 3]
        else:
            q1 = lista_ordenada[tamanho // 4]
            q3 = lista_ordenada[tamanho // 4 * 3]
        return q3 - q1

    def percentil(self, percentil):
        lista_ordenada = sorted(self.lista)
        tamanho = len(lista_ordenada)
        if percentil == 0:
            return lista_ordenada[0]
        elif percentil == 100:
            return lista_ordenada[tamanho - 1]
        else:
            posicao = (percentil / 100) * (tamanho - 1)
            if posicao.is_integer():
                return lista_ordenada[int(posicao)]
            else:
                return lista_ordenada[int(posicao)] + (posicao - int(posicao)) * (lista_ordenada[int(posicao) + 1] - lista_ordenada[int(posicao)])

# %%
def analise_exploratoria(df, tabela = None):
    df.info()
    print("\n")
    print("Estatísticas Descritivas")
    display(df.describe())
    print("\n")
    print("Correlação")
    display(df.corr())
    print("\n")
    if tabela:
        print(f"Tabela - {tabela}")
        df.tabela.describe().to_frame()


def show_info(df):
    print(df.columns)
    display(df)
    analise_exploratoria(df)

def show_dataframe(txt,df):
    print(txt)
    display(df)

# %%
import pandas as pd

sheets = ["RES MOTORES","RES MNT","RES VAL","C BRILHANTE","C DIAMANTE"]
titulo = ""

for i in range(len(sheets)):

    df_preventiva = pd.read_excel("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Jedi Cyberpunk 2024/Ciencia de dados/datasets/preventiva_azimutails _2024-03-25.xlsx",
                                sheet_name=sheets[i])

    if i== 0:
        titulo = "MOTORES"
        print(
            f"Preventiva - {titulo}\nSheet = {sheets[i]}"
        )
    
        df_brilhante = df_preventiva.iloc[:,5:9]
        df_diamante = df_preventiva.iloc[:,15:20]
        show_dataframe("Brilhante",df_brilhante)
        show_dataframe("Diamante",df_diamante)

    if i== 1:
        titulo = "MANUTENÇÃO"

        print(
            f"Preventiva - {titulo}\nSheet = {sheets[i]}"
        )
    
        df_brilhante = df_preventiva.iloc[:,0:4]
        df_diamante = df_preventiva.iloc[:,10:14]
        show_dataframe("Brilhante",df_brilhante)
        show_dataframe("Diamante",df_diamante)
# Out:
# Preventiva - MOTORES
# Sheet = RES MOTORES
# Brilhante
#             C BRILHANTE              Unnamed: 6   Unnamed: 7 Unnamed: 8
# 0   2024-03-19 00:00:00                 H/TRAB.  PROX. TROCA    H/TROCA
# 1               MCP-BB:                   29805        30371        566
# 2               MCP-BE:                   30035        30465        430
# 3            MCA-01 BB:                    6300         6550        250
# 4            MCA-02 BE:                    6300         6550        250
# 5               Qt. MCP       800 L x 2 Motores          NaN        NaN
# 6              Tipo MCP  15w40 CI4, Alta Perfom          NaN        NaN
# 7               Qt. MCA        20 l x 2 Motores          NaN        NaN
# 8              Tipo MCA             15w40 CH4\t          NaN        NaN
# 9                   NaN                     NaN          NaN        NaN
# 10               C JADE                     NaN          NaN        NaN
# 11  2024-03-20 00:00:00                 H/TRAB.  PROX. TROCA    H/TROCA
# 12              MCP-BB:                   13421        13624        203
# 13              MCP-BE:                   13522        13875        353
# 14           MCA-01 BB:                   25566        25630         64
# 15           MCA-02 BE:                   25709        25810        101
# 16              Qt. MCP       280 L x 2 Motores          NaN        NaN
# 17             Tipo MCP  15w40 CI4, Alta Perfom          NaN        NaN
# 18              Qt. MCA        20 l x 2 Motores          NaN        NaN
# 19             Tipo MCA             15w40 CH4\t          NaN        NaN
# 20                  NaN                     NaN          NaN        NaN
# 21            C TOPÁZIO                     NaN          NaN        NaN
# 22  2024-03-20 00:00:00                 H/TRAB.  PROX. TROCA    H/TROCA
# 23              MCP-BB:                   19288        19661        373
# 24              MCP-BE:                    2930         3049        119
# 25           MCA-01 BB:                   22292        22500        208
# 26           MCA-02 BE:                   21277        21360         83
# 27              Qt. MCP       280 L x 2 Motores          NaN        NaN
# 28             Tipo MCP  15w40 CI4, Alta Perfom          NaN        NaN
# 29              Qt. MCA        20 L x 2 Motores          NaN        NaN
# 30             Tipo MCA             15w40 CH4\t          NaN        NaN
# 31                  NaN                     NaN          NaN        NaN
# 32  JOSÉ GUILHERME VIII                     NaN          NaN        NaN
# 33  2024-03-20 00:00:00                 H/TRAB.  PROX. TROCA    H/TROCA
# 34              MCP-BB:                    6810         7281        471
# 35              MCP-BE:                    6782         7254        472
# 36           MCA-01 BB:                    7803         8020        217
# 37           MCA-02 BE:                    7400         7650        250
# 38              Qt. MCP       800 L x 2 motores          NaN        NaN
# 39             Tipo MCP  15w40 CI4, Alta Perfom          NaN        NaN
# 40              Qt. MCA        20 L x 2 Motores          NaN        NaN
# 41             Tipo MCA             15w40 CH4\t          NaN        NaN
# 42                  NaN                     NaN          NaN        NaN
# 43             CAILLEAN                     NaN          NaN        NaN
# 44  2024-03-19 00:00:00                 H/TRAB.  PROX. TROCA    H/TROCA
# 45              MCP-BB:                   25400        25425         25
# 46              MCP-BE:                   23745        23770         25
# 47           MCA-01 BB:                    6826         6944        118
# 48           MCA-02 BE:                   10107        10357        250
# 49              Qt. MCP       600 L x 2 motores          NaN        NaN
# 50             Tipo MCP  15w40 CI4, Alta Perfom          NaN        NaN
# 51              Qt. MCA         20 L x2 motores          NaN        NaN
# 52             Tipo MCA             15w40 CH4\t          NaN        NaN
# Diamante
#              C DIAMANTE             Unnamed: 16  Unnamed: 17 Unnamed: 18
# 0   2024-03-20 00:00:00                 H/TRAB.  PROX. TROCA     H/TROCA
# 1               MCP-BB:                   35867        35947          80
# 2               MCP-BE:                   36008        36941         933
# 3            MCA-01 BB:                   37956        38206         250
# 4            MCA-02 BE:                   38540        38673         133
# 5               Qt. MCP       800 L x 2 Motores          NaN         NaN
# 6              Tipo MCP  15w40 CI4, Alta Perfom          NaN         NaN
# 7               Qt. MCA        20 l x 2 Motores          NaN         NaN
# 8              Tipo MCA             15w40 CH4\t          NaN         NaN
# 9                   NaN                     NaN          NaN         NaN
# 10             C PÉROLA                     NaN          NaN         NaN
# 11  2024-03-20 00:00:00                 H/TRAB.  PROX. TROCA     H/TROCA
# 12              MCP-BB:                   27035        27212         177
# 13              MCP-BE:                   28435        28612         177
# 14        MCA-01 VANTE:                   12050        12104          54
# 15           MCA-02 RÉ:                   11871        12115         244
# 16              Qt. MCP       280 L x 2 Motores          NaN         NaN
# 17             Tipo MCP  15w40 CI4, Alta Perfom          NaN         NaN
# 18              Qt. MCA        20 l x 2 Motores          NaN         NaN
# 19             Tipo MCA             15w40 CH4\t          NaN         NaN
# 20                  NaN                     NaN          NaN         NaN
# 21           C TURQUESA                     NaN          NaN         NaN
# 22  2024-03-18 00:00:00                 H/TRAB.  PROX. TROCA     H/TROCA
# 23              MCP-BB:                    2978         3304         326
# 24              MCP-BE:                   10963        11246         283
# 25           MCA-01 BB:                   31998        32231         233
# 26           MCA-02 BE:                   30754        31004         250
# 27              Qt. MCP       280 L x 2 Motores          NaN         NaN
# 28             Tipo MCP  15w40 Lubrax Top Turbo          NaN         NaN
# 29              Qt. MCA        20 L x 2 Motores          NaN         NaN
# 30             Tipo MCA             15w40 CH4\t          NaN         NaN
# 31                  NaN                     NaN          NaN         NaN
# 32          STAR SIRIUS                     NaN          NaN         NaN
# 33  2024-03-19 00:00:00                 H/TRAB.  PROX. TROCA     H/TROCA
# 34              MCP-BB:                   11267        11355          88
# 35              MCP-BE:                    6457         6676         219
# 36           MCA-01 BB:                   12115        12344         229
# 37           MCA-02 BE:                   28918        29168         250
# 38              Qt. MCP       280 L x 2 Motores          NaN         NaN
# 39             Tipo MCP  15w40 CI4, Alta Perfom          NaN         NaN
# 40              Qt. MCA        20 L x 2 Motores          NaN         NaN
# 41             Tipo MCA             15w40 CH4\t          NaN         NaN
# 42                  NaN                     NaN          NaN         NaN
# 43                  NaN                     NaN          NaN         NaN
# 44                  NaN                     NaN          NaN         NaN
# 45                  NaN                     NaN          NaN         NaN
# 46                  NaN                     NaN          NaN         NaN
# 47                  NaN                     NaN          NaN         NaN
# 48                  NaN                     NaN          NaN         NaN
# 49                  NaN                     NaN          NaN         NaN
# 50                  NaN                     NaN          NaN         NaN
# 51                  NaN                     NaN          NaN         NaN
# 52                  NaN                     NaN          NaN         NaN
# Preventiva - MANUTENÇÃO
# Sheet = RES MNT
# Brilhante
#               C BRILHANTE           Unnamed: 1           Unnamed: 2  \
# 0     2024-03-25 00:00:00                TROCA          PROX. TROCA
# 1     PTO BB ÓLEO RESERVA              reserva                   90
# 2             PTO BE ÓLEO  2023-12-12 00:00:00  2024-03-11 00:00:00
# 3   PTO BB FILTRO RESERVA              reserva                  180
# 4           PTO BE FILTRO  2023-11-21 00:00:00  2024-05-19 00:00:00
# ..                    ...                  ...                  ...
# 79   PROP - FILTRO LUB BE  2023-10-08 00:00:00               Alarme
# 80  PROP - FILTRO HIDR BB  2023-10-27 00:00:00  2024-04-24 00:00:00
# 81  PROP - FILTRO HIDR BE  2023-10-27 00:00:00  2024-04-24 00:00:00
# 82    TQ HIDR AZM BB ÓLEO             00:00:00  1901-12-20 00:00:00
# 83    TQ HIDR AZM BE ÓLEO             00:00:00  1901-12-20 00:00:00
#
#     Unnamed: 3
# 0   DIAS/TROCA
# 1      RESERVA
# 2          -14
# 3      RESERVA
# 4           55
# ..         ...
# 79         169
# 80          30
# 81          30
# 82         NaN
# 83         NaN
#
# [84 rows x 4 columns]
# Diamante
#              C DIAMANTE          Unnamed: 11          Unnamed: 12 Unnamed: 13
# 0   2024-03-25 00:00:00                TROCA          PROX. TROCA  DIAS/TROCA
# 1           PTO BB ÓLEO  2024-01-06 00:00:00  2024-04-05 00:00:00          11
# 2           PTO BE ÓLEO  2024-03-15 00:00:00  2024-06-13 00:00:00          80
# 3         PTO BB FILTRO  2023-12-27 00:00:00  2024-06-24 00:00:00          91
# 4         PTO BE FILTRO  2023-12-27 00:00:00  2024-06-24 00:00:00          91
# ..                  ...                  ...                  ...         ...
# 79                  NaN                  NaN                  NaN         NaN
# 80                  NaN                  NaN                  NaN         NaN
# 81                  NaN                  NaN                  NaN         NaN
# 82                  NaN                  NaN                  NaN         NaN
# 83                  NaN                  NaN                  NaN         NaN
#
# [84 rows x 4 columns]
