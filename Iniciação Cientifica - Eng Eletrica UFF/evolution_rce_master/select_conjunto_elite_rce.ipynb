# %% [markdown]
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE
#
# -Sobre a visualização dos dados:
#   + manter o gráfico de convergência (retirando a soma e corrigindo o Best para Max) e os dados associados
#   + apresentar a melhor solução no final - valores das variáveis de decisão e valor da aptidão
#   + incluir tempo de execução total
# - Falta implementar o elitismo simples
# - Falta implementar a repopulação
# - Depois que tudo funcionar :
#   + Armazenar várias execuções do algoritmo em sequencia e extrair média e desvio padrão da melhor solução (ótimo) e dos tempos de execução.

# %% [markdown]
# 1 - O RCE vai descobrir o array com os x indivíduos do offspring que precisam ser copiados.
# 2 - Criar uma população popRCE de x + 1 indivíduos.
# 3 - Copiar o indivíduo elite para o [0] desta população popRCE.
# 4 - Copiar os x indivíduos do offspring cujo índice está no array para o popRCE a partir de [1].
# 5 - Criar uma população popnew com popsize - x - 1 indivíduos (verificar se quando cria a pop no DEAP ele já calcula o fitness).
# 6 - Copiar popRCE para o topo [0] do pop;
# 7 - Copiar popnew para a posição x + 1 do pop;

# %% [markdown]
# ## Interface beta

# %%
import easygui

def show_input_form(default_data):
    """
    Exibe um formulário de entrada com valores padrão e permite edição através de uma lista suspensa.
    
    Args:
        default_data (dict): Dicionário contendo os valores padrão para os campos.
    
    Returns:
        dict: Dicionário contendo os dados preenchidos pelo usuário.
    """
    data_dict = {}

    for field_name, default_value in default_data.items():
        # Verifica se o valor padrão não é uma lista, o que indica um campo de entrada
        if not isinstance(default_value, list):
            # Exibe um input para o campo
            value = easygui.enterbox(f"Digite o valor para '{field_name}':", field_name, default_value)
            data_dict[field_name] = value

    return data_dict

# Define os valores padrão para os campos
default_values = {
    "CROSSOVER": 0.9,
    "TAXA MUTACAO": 0.05,
    "GENERATIONS": 100,
    "POP_SIZE": 100,
    "IND_SIZE": 10,
    "evaluations": 0,
    "num_genes": 5
}

# Chama a função para exibir o formulário de entrada com valores padrão
input_data = show_input_form(default_values)

# Verifica se o formulário foi preenchido e exibe os dados
if input_data is not None:
    print("Dados preenchidos:")
    for key, value in input_data.items():
        print(f"{key}: {value}")
else:
    print("Operação cancelada pelo usuário.")

# Exibe a tela para escolha do tipo de otimização (minimização/máximação)
min_max_choice = easygui.buttonbox("Selecione o tipo de otimização:", "Minimize/Maximize", choices=["Minimize", "Maximize"])
print(f"Tipo de otimização selecionado: {min_max_choice}")

# Exibe a tela para escolha da função objetivo (Rastrigin ou Sphere)
function_choice = easygui.buttonbox("Selecione a função objetivo:", "Função Objetivo", choices=["Rastrigin", "Sphere"])
print(f"Função objetivo selecionada: {function_choice}")
# Out:
# Dados preenchidos:
# CROSSOVER: 0.9
# TAXA MUTACAO: 0.05
# GENERATIONS: 100
# POP_SIZE: 100
# IND_SIZE: 10
# evaluations: 0
# num_genes: 5
# Tipo de otimização selecionado: Minimize
# Função objetivo selecionada: Rastrigin

# %%
from src.models.Setup import Setup
from src.models.DataExploration import DataExploration
from src.models.AlgEvolution import AlgEvolution
import time
from src.backend.pdf_generator import PDFGenerator
import json
import pandas as pd

from IPython.display import display


def load_params(file_path):
    with open(file_path, "r") as file:
        params = json.load(file)
    return params



def main():
    tempo1 = time.time()




    #Setup
    params = load_params("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Iniciação Cientifica - Eng Eletrica UFF/evolution_rce_master/src/db/parameters.json")
    data_visual = DataExploration()
    setup = Setup(params)
    alg = AlgEvolution(setup)
    pop_with_repopulation, logbook_with_repopulation, best_variables = alg.run(RCE=True)
    print("\nEvolução concluída  - 100%")




    # Salvar resultados
    all_df = data_visual.displayDataFrameInfo(alg.allIndividualValuesArray, "\n\nTodos Individuos Gerados")
    print("\n\n-->Conjunto Elite:", alg.pop_RCE)
    best_df = pd.DataFrame(alg.pop_RCE)
    display(best_df.sort_values(by = "Fitness" ,ascending=False))
    print(best_df.shape)

    print("\nResults RCE")
    alg.combinar_aleatoriamente()
    #data_visual.plot_grafico_barras(setup.NGEN,best_df["Fitness"])


    

    
    # Visualização dos resultados
    print("\n\nVISUALIZANDO OS RESULTADOS")
    #TODO data_visual.displayDataFrameInfo(alg.best_individual_array, "Best 100 variables with repopulation")
    data_visual.visualize(
        logbook_with_repopulation, pop_with_repopulation, repopulation=True
    )
    data_visual.statistics_per_generation_df(logbook_with_repopulation)
    data_visual.plot_diversidade_genes(pop_with_repopulation)






















    tempo2 = time.time()
    print(f"Total execution time: {round(tempo2-tempo1,2)} seconds")
main()
# Out:
# /home/pedrov/.local/lib/python3.11/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/pedrov/.local/lib/python3.11/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# RCE being applied!  - Generation = 20
# TAMANHO ATUAL DE TODOS INDIVIDUOS 2000
#
#
# Melhor da geração: 15
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 1417           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
#
#        Fitness     Media  Desvio Padrao  RCE
# 1417  8.535916  9.543642       0.595361   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(87) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(69) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(62) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(37) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(83) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(47) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(73) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(52) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(97) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 19, 'index': 97, 'Variaveis de Decisão': [0.9853838843888995, 0.10668679773077161, 1.3396561247202081, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.9978318261728062], 'Fitness': 25.40810002524579, 'Media': 9.22203301749874, 'Desvio Padrao': 3.9664241069191233, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 10) = 2 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1            5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   8.535916   9.543642       0.595361   -
# 1  55.263934  41.469257      11.919570   -
# RCE being applied!  - Generation = 40
# TAMANHO ATUAL DE TODOS INDIVIDUOS 4000
#
#
# Melhor da geração: 22
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 2124           22     24  [0.9853838843888995, -0.9311849157702877, 0.03...
#
#        Fitness     Media  Desvio Padrao  RCE
# 2124  8.148069  8.665709       0.767811   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(84) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(40) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 26, 'index': 40, 'Variaveis de Decisão': [0.9853838843888995, -0.9311849157702877, 2.4122857839329113, 1.9004062167123101, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.9978318261728062], 'Fitness': 36.71980172332654, 'Media': 9.248689542612606, 'Desvio Padrao': 4.883815461626962, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 13) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1            5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 2            9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   8.535916   9.543642       0.595361   -
# 1  55.263934  41.469257      11.919570   -
# 2  40.792303  18.899991       4.243879   -
# RCE being applied!  - Generation = 60
# TAMANHO ATUAL DE TODOS INDIVIDUOS 6000
#
#
# Melhor da geração: 59
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 5815           59     15  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 5815  7.064645  7.953753       1.914779   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(46) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(6) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(0) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(44) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(50) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(63) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(16) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 53, 'index': 16, 'Variaveis de Decisão': [0.9853838843888995, -0.9311849157702877, 0.32188410410141216, 0.986061548999926, 0.0536916965991493, -0.3223628058391328, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, -0.26469055830835864], 'Fitness': 45.845969372691755, 'Media': 8.965546151569836, 'Desvio Padrao': 4.6204721800795205, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 21) = 5 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1            5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 2            9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
# 3           10     62  [0.9853838843888995, 0.8481191834448232, 2.913...
# 4           10     37  [-0.825005641036786, -0.1482777122553126, 0.03...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   8.535916   9.543642       0.595361   -
# 1  55.263934  41.469257      11.919570   -
# 2  40.792303  18.899991       4.243879   -
# 3  21.884469  16.063407       3.652158   -
# 4  21.142463  16.063407       3.652158   -
# RCE being applied!  - Generation = 80
# TAMANHO ATUAL DE TODOS INDIVIDUOS 8000
#
#
# Melhor da geração: 59
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 5815           59     15  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 5815  7.064645  7.953753       1.914779   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(60) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 77, 'index': 60, 'Variaveis de Decisão': [0.04086437033305346, -0.9311849157702877, 0.03645466739822967, 0.986061548999926, 2.0642895976482154, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 1.4786872285628854, 0.055120859702736946], 'Fitness': 32.543523064246685, 'Media': 7.730782693800324, 'Desvio Padrao': 3.6857055770687017, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 23) = 5 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1            5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 2            9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
# 3           10     62  [0.9853838843888995, 0.8481191834448232, 2.913...
# 4           10     37  [-0.825005641036786, -0.1482777122553126, 0.03...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   8.535916   9.543642       0.595361   -
# 1  55.263934  41.469257      11.919570   -
# 2  40.792303  18.899991       4.243879   -
# 3  21.884469  16.063407       3.652158   -
# 4  21.142463  16.063407       3.652158   -
# RCE being applied!  - Generation = 100
# TAMANHO ATUAL DE TODOS INDIVIDUOS 10000
#
#
# Melhor da geração: 94
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 9304           94      4  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 9304  6.816395  7.062162       0.024701   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(26) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 84, 'index': 26, 'Variaveis de Decisão': [0.04086437033305346, -0.49589667380541397, 1.482865605903548, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.055120859702736946], 'Fitness': 47.3983362653251, 'Media': 8.230617270399032, 'Desvio Padrao': 5.46381561979118, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 25) = 5 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1            5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 2            9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
# 3           10     62  [0.9853838843888995, 0.8481191834448232, 2.913...
# 4           10     37  [-0.825005641036786, -0.1482777122553126, 0.03...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   8.535916   9.543642       0.595361   -
# 1  55.263934  41.469257      11.919570   -
# 2  40.792303  18.899991       4.243879   -
# 3  21.884469  16.063407       3.652158   -
# 4  21.142463  16.063407       3.652158   -
# Evolução concluída  - 100%
# =================================================================
#
#
# Todos Individuos Gerados
# =================================================================
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.1698848231816088, 0.07758267004042274, 0.10...
# 1               1      1  [0.5946877850405959, 0.4311449318241052, 0.855...
# 2               1      2  [0.9537205835365158, 0.30270760278405306, 0.76...
# 3               1      3  [0.9860239987766851, 0.192832304010077, 0.4897...
# 4               1      4  [0.35107019832293695, 0.4523345494226423, 0.69...
# ...           ...    ...                                                ...
# 9995          100     95  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9996          100     96  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9997          100     97  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9998          100     98  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9999          100     99  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#          Fitness       Media  Desvio Padrao  RCE
# 0      95.003438  105.670621      22.602105   -
# 1     111.905166  105.670621      22.602105   -
# 2     106.202687  105.670621      22.602105   -
# 3      95.588008  105.670621      22.602105   -
# 4     113.080823  105.670621      22.602105   -
# ...          ...         ...            ...  ...
# 9995    6.816395    8.049964       6.615842   -
# 9996    6.816395    8.049964       6.615842   -
# 9997    6.816395    8.049964       6.615842   -
# 9998    6.816395    8.049964       6.615842   -
# 9999    6.816395    8.049964       6.615842   -
#
# [10000 rows x 7 columns]
# -->Conjunto Elite: [{'Generations': 15, 'index': 17, 'Variaveis de Decisão': [0.9853838843888995, 0.10668679773077161, 0.03645466739822967, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.9978318261728062], 'Fitness': 8.535915704482605, 'Media': 9.543641573177608, 'Desvio Padrao': 0.5953606202659273, 'RCE': ' - '}, {'Generations': 5, 'index': 87, 'Variaveis de Decisão': [3.1293382311013294, 0.8819162355255495, -0.7700249814629228, 0.09283479039871934, 0.7966281103830758, 0.9579854498613701, 0.8589348862377393, 0.7652183563963578, 0.9995649087984402, 0.14485145174549163], 'Fitness': 55.26393389902215, 'Media': 41.46925685898304, 'Desvio Padrao': 11.919570229337886, 'RCE': ' - '}, {'Generations': 9, 'index': 69, 'Variaveis de Decisão': [-0.5150572066528173, 0.8819162355255495, 0.03645466739822967, 0.09283479039871934, 0.18060737855123477, 0.9992228381777772, 0.1538603149136042, 0.9451187184819405, 0.9388417989918735, 0.9978318261728062], 'Fitness': 40.792303079392866, 'Media': 18.899991399322843, 'Desvio Padrao': 4.243879373806792, 'RCE': ' - '}, {'Generations': 10, 'index': 62, 'Variaveis de Decisão': [0.9853838843888995, 0.8481191834448232, 2.91366994918724, 0.986061548999926, 0.9985080312396621, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.9388417989918735, 0.9978318261728062], 'Fitness': 21.884468637047444, 'Media': 16.06340655339634, 'Desvio Padrao': 3.652157936003404, 'RCE': ' - '}, {'Generations': 10, 'index': 37, 'Variaveis de Decisão': [-0.825005641036786, -0.1482777122553126, 0.03645466739822967, 0.09283479039871934, 0.18060737855123477, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.9647581555102049, -0.057218536908630324], 'Fitness': 21.142463437013873, 'Media': 16.06340655339634, 'Desvio Padrao': 3.652157936003404, 'RCE': ' - '}, {'Generations': 11, 'index': 83, 'Variaveis de Decisão': [0.9153823779189382, -0.3182352498485249, 1.2750581521291933, 1.1452353279789533, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.9451187184819405, 0.9388417989918735, 0.9978318261728062], 'Fitness': 40.646438957954174, 'Media': 14.196568685409527, 'Desvio Padrao': 4.621434963135614, 'RCE': ' - '}, {'Generations': 12, 'index': 47, 'Variaveis de Decisão': [0.9153823779189382, 0.8819162355255495, 0.03645466739822967, -0.27024359810676235, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.9388417989918735, 2.8191463774249637], 'Fitness': 34.53777805852897, 'Media': 12.517585777133053, 'Desvio Padrao': 4.305314648516593, 'RCE': ' - '}, {'Generations': 18, 'index': 73, 'Variaveis de Decisão': [0.9853838843888995, 0.10668679773077161, 1.8614387738874152, 0.986061548999926, 0.0536916965991493, -1.4935471932533437, 0.025370679768010995, 0.036808255777676324, 2.2694419454311614, 0.9978318261728062], 'Fitness': 51.76986254771607, 'Media': 9.310642163309637, 'Desvio Padrao': 4.826735670503105, 'RCE': ' - '}, {'Generations': 19, 'index': 52, 'Variaveis de Decisão': [0.9853838843888995, 0.10668679773077161, 0.338905637643112, 2.048176471742573, 0.0536916965991493, 0.9992228381777772, -1.1486583050514096, -1.817447706414268, 0.07576747017422647, 0.9978318261728062], 'Fitness': 41.49689727264776, 'Media': 9.22203301749874, 'Desvio Padrao': 3.9664241069191233, 'RCE': ' - '}, {'Generations': 19, 'index': 97, 'Variaveis de Decisão': [0.9853838843888995, 0.10668679773077161, 1.3396561247202081, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.9978318261728062], 'Fitness': 25.40810002524579, 'Media': 9.22203301749874, 'Desvio Padrao': 3.9664241069191233, 'RCE': ' - '}, {'Generations': 22, 'index': 24, 'Variaveis de Decisão': [0.9853838843888995, -0.9311849157702877, 0.03645466739822967, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, 0.036808255777676324, 0.07576747017422647, 0.9 ...
#     Generations  index                               Variaveis de Decisão  \
# 1             5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 7            18     73  [0.9853838843888995, 0.10668679773077161, 1.86...
# 24           84     26  [0.04086437033305346, -0.49589667380541397, 1....
# 20           53     16  [0.9853838843888995, -0.9311849157702877, 0.32...
# 8            19     52  [0.9853838843888995, 0.10668679773077161, 0.33...
# 2             9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
# 5            11     83  [0.9153823779189382, -0.3182352498485249, 1.27...
# 11           26     84  [0.9853838843888995, -0.9311849157702877, 0.03...
# 16           44      0  [0.9853838843888995, -0.9311849157702877, 0.03...
# 12           26     40  [0.9853838843888995, -0.9311849157702877, 2.41...
# 6            12     47  [0.9153823779189382, 0.8819162355255495, 0.036...
# 18           47     50  [2.56490372877957, -0.9311849157702877, 0.0364...
# 22           77     60  [0.04086437033305346, -0.9311849157702877, 0.0...
# 14           42     46  [0.9853838843888995, -0.9311849157702877, -1.0...
# 15           42      6  [-0.6917004028727453, -0.9311849157702877, 0.0...
# 17           45     44  [0.9853838843888995, -0.9311849157702877, 0.03...
# 9            19     97  [0.9853838843888995, 0.10668679773077161, 1.33...
# 19           47     63  [0.9853838843888995, 1.3322470468157817, 0.036...
# 3            10     62  [0.9853838843888995, 0.8481191834448232, 2.913...
# 4            10     37  [-0.825005641036786, -0.1482777122553126, 0.03...
# 0            15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 10           22     24  [0.9853838843888995, -0.9311849157702877, 0.03...
# 13           59     15  [0.04086437033305346, -0.9311849157702877, 0.0...
# 21           59     15  [0.04086437033305346, -0.9311849157702877, 0.0...
# 23           94      4  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#       Fitness      Media  Desvio Padrao  RCE
# 1   55.263934  41.469257      11.919570   -
# 7   51.769863   9.310642       4.826736   -
# 24  47.398336   8.230617       5.463816   -
# 20  45.845969   8.965546       4.620472   -
# 8   41.496897   9.222033       3.966424   -
# 2   40.792303  18.899991       4.243879   -
# 5   40.646439  14.196569       4.621435   -
# 11  37.962337   9.248690       4.883815   -
# 16  36.790670   9.046560       4.122483   -
# 12  36.719802   9.248690       4.883815   -
# 6   34.537778  12.517586       4.305315   -
# 18  32.893626   9.218800       4.694833   -
# 22  32.543523   7.730783       3.685706   -
# 14  28.541142   9.116733       3.860574   -
# 15  27.684040   9.116733       3.860574   -
# 17  26.643041   9.104593       4.010622   -
# 9   25.408100   9.222033       3.966424   -
# 19  23.504994   9.218800       4.694833   -
# 3   21.884469  16.063407       3.652158   -
# 4   21.142463  16.063407       3.652158   -
# 0    8.535916   9.543642       0.595361   -
# 10   8.148069   8.665709       0.767811   -
# 13   7.064645   7.953753       1.914779   -
# 21   7.064645   7.953753       1.914779   -
# 23   6.816395   7.062162       0.024701   -
# (25, 7)
#
# Results RCE
#       Generations  index                               Variaveis de Decisão  \
# 0              15     17  [0.9853838843888995, 0.10668679773077161, 0.03...
# 1               5     87  [3.1293382311013294, 0.8819162355255495, -0.77...
# 2               9     69  [-0.5150572066528173, 0.8819162355255495, 0.03...
# 3              10     62  [0.9853838843888995, 0.8481191834448232, 2.913...
# 4              10     37  [-0.825005641036786, -0.1482777122553126, 0.03...
# ...           ...    ...                                                ...
# 9984          100     84  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9927          100     27  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9972          100     72  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9919          100     19  [0.04086437033305346, -0.9311849157702877, 0.0...
# 9991          100     91  [0.04086437033305346, -0.9311849157702877, 0.0...
#
#         Fitness      Media  Desvio Padrao  RCE
# 0      8.535916   9.543642       0.595361  SIM
# 1     55.263934  41.469257      11.919570  SIM
# 2     40.792303  18.899991       4.243879  SIM
# 3     21.884469  16.063407       3.652158  SIM
# 4     21.142463  16.063407       3.652158  SIM
# ...         ...        ...            ...  ...
# 9984   6.816395   8.049964       6.615842  NÃO
# 9927   6.816395   8.049964       6.615842  NÃO
# 9972   6.816395   8.049964       6.615842  NÃO
# 9919   6.816395   8.049964       6.615842  NÃO
# 9991   6.816395   8.049964       6.615842  NÃO
#
# [100 rows x 7 columns]
# VISUALIZANDO OS RESULTADOS
# =================================================================
# Soluções do problema
# =================================================================
#
# Best solution index =  92
#
# Best solution variables =
#  [0.04086437033305346, -0.9311849157702877, 0.03645466739822967, 0.986061548999926, 0.0536916965991493, 0.9992228381777772, 0.025370679768010995, -0.009877965163222556, 0.07576747017422647, 0.055120859702736946]
#
# Best solution fitness =  6.816395486209025
#
# Ótimo global da função Rastrigin =  2.9981134503261444
#
# Solução ótima global =  [-1.51079731e-03 -9.91911991e-01 -2.60806526e-03  9.92395426e-01
#   1.14938571e-04  9.97144449e-01 -2.05480189e-03 -4.38613462e-03
#  -2.00102538e-03  3.08877857e-03]
#
# Porcentagem de proximidade da solução em relação ao ótimo global =  -127.35615576747156 %
#
# Distância da solução em relação ao ótimo global = <built-in function abs>
# 100 100 100
# Plotando diversidade dos genes
# Total execution time: 9.49 seconds
