# %% [markdown]
# 1 - O RCE vai descobrir o array com os x indivíduos do offspring que precisam ser copiados.
# 2 - Criar uma população popRCE de x + 1 indivíduos.
# 3 - Copiar o indivíduo elite para o [0] desta população popRCE.
# 4 - Copiar os x indivíduos do offspring cujo índice está no array para o popRCE a partir de [1].
# 5 - Criar uma população popnew com popsize - x - 1 indivíduos (verificar se quando cria a pop no DEAP ele já calcula o fitness).
# 6 - Copiar popRCE para o topo [0] do pop;
# 7 - Copiar popnew para a posição x + 1 do pop;

# %% [markdown]
# ---
#
# 5ª Reunião (Remota)
# -Sobre a visualização dos dados:
#   + manter o gráfico de convergência (retirando a soma e corrigindo o Best para Max) e os dados associados
#   + apresentar a melhor solução no final - valores das variáveis de decisão e valor da aptidão
#   + incluir tempo de execução total
# - Falta implementar o elitismo simples
#
# 6ª Reunião (Remota)
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE
#
# 7ª Reunião (Remota)
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE

# %% [markdown]
# ## Interface beta

# %%
import easygui

def show_input_form(default_data):
    """
    Exibe um formulário de entrada com valores padrão e permite edição através de uma lista suspensa.
    
    Args:
        default_data (dict): Dicionário contendo os valores padrão para os campos.
    
    Returns:
        dict: Dicionário contendo os dados preenchidos pelo usuário.
    """
    data_dict = {}

    for field_name, default_value in default_data.items():
        # Verifica se o valor padrão não é uma lista, o que indica um campo de entrada
        if not isinstance(default_value, list):
            # Exibe um input para o campo
            value = easygui.enterbox(f"Digite o valor para '{field_name}':", field_name, default_value)
            data_dict[field_name] = value

    return data_dict

# Define os valores padrão para os campos
default_values = {
    "CROSSOVER": 0.9,
    "TAXA MUTACAO": 0.05,
    "GENERATIONS": 100,
    "POP_SIZE": 100,
    "IND_SIZE": 10,
    "evaluations": 0,
    "num_genes": 5
}

# Chama a função para exibir o formulário de entrada com valores padrão
input_data = show_input_form(default_values)

# Verifica se o formulário foi preenchido e exibe os dados
if input_data is not None:
    print("Dados preenchidos:")
    for key, value in input_data.items():
        print(f"{key}: {value}")
else:
    print("Operação cancelada pelo usuário.")

# Exibe a tela para escolha do tipo de otimização (minimização/máximação)
min_max_choice = easygui.buttonbox("Selecione o tipo de otimização:", "Minimize/Maximize", choices=["Minimize", "Maximize"])
print(f"Tipo de otimização selecionado: {min_max_choice}")

# Exibe a tela para escolha da função objetivo (Rastrigin ou Sphere)
function_choice = easygui.buttonbox("Selecione a função objetivo:", "Função Objetivo", choices=["Rastrigin", "Sphere"])
print(f"Função objetivo selecionada: {function_choice}")
# Out:
# Dados preenchidos:
# CROSSOVER: 0.9
# TAXA MUTACAO: 0.05
# GENERATIONS: 100
# POP_SIZE: 100
# IND_SIZE: 10
# evaluations: 0
# num_genes: 5
# Tipo de otimização selecionado: Minimize
# Função objetivo selecionada: Rastrigin

# %% [markdown]
# ## Evolution

# %%
from src.models.Setup import Setup
from src.models.DataExploration import DataExploration
from src.models.AlgEvolution import AlgEvolution
import time
from src.backend.pdf_generator import PDFGenerator
import json
import pandas as pd

from IPython.display import display


def load_params(file_path):
    with open(file_path, "r") as file:
        params = json.load(file)
    return params



def main():
    tempo1 = time.time()

    data ={
        "CXPB": 0.9,
        "MUTPB": 0.05,
        "NGEN": 100,
        "POP_SIZE": 100,
        "IND_SIZE": 10,
        "evaluations": 0,
        "type": "Minimaze",
        "funcao objetivo": "Rastrigin",
        "num_genes": 5,
        "Variaveis decisao": [],
        "label": " "
    }


    #Setup
    params = load_params("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Iniciação Cientifica - Eng Eletrica UFF/evolution_rce_master/src/db/parameters.json")
    data_visual = DataExploration()
    setup = Setup(params)
    alg = AlgEvolution(setup)
    pop_with_repopulation, logbook_with_repopulation, best_variables = alg.run(RCE=True)
    print("\nEvolução concluída  - 100%")




    # Salvar resultados
    all_df = data_visual.displayDataFrameInfo(alg.allIndividualValuesArray, "\n\nTodos Individuos Gerados")
    print("\n\n-->Conjunto Elite:", alg.pop_RCE)
    best_df = pd.DataFrame(alg.pop_RCE)
    display(best_df.sort_values(by = "Fitness" ,ascending=False))
    print(best_df.shape)

    print("\nResults RCE")
    alg.combinar_aleatoriamente()
    data_visual.plot_grafico_barras(setup.NGEN,best_df["Fitness"])


    

    
    # Visualização dos resultados
    print("\n\nVISUALIZANDO OS RESULTADOS")
    #TODO data_visual.displayDataFrameInfo(alg.best_individual_array, "Best 100 variables with repopulation")
    data_visual.visualize(
        logbook_with_repopulation, pop_with_repopulation, repopulation=True
    )
    data_visual.statistics_per_generation_df(logbook_with_repopulation)
    data_visual.plot_diversidade_genes(pop_with_repopulation)






















    tempo2 = time.time()
    print(f"Total execution time: {round(tempo2-tempo1,2)} seconds")
main()
# Out:
# RCE being applied!  - Generation = 20
# TAMANHO ATUAL DE TODOS INDIVIDUOS 2000
#
#
# Melhor da geração: 13
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 1257           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#        Fitness     Media  Desvio Padrao  RCE
# 1257  5.057422  7.638379       2.700887   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(97) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 19, 'index': 97, 'Variaveis de Decisão': [2.047686851420459, 0.9925989370895953, 0.0652293519464483, -1.5153058463869216, 0.00973253073010194, 0.037786250677055655, 0.02425113467967499, 0.07181974847878647, 0.0283158166023314, 0.08224094965322404], 'Fitness': 31.61138875023194, 'Media': 6.1301283224487175, 'Desvio Padrao': 4.647723060799118, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 2) = 1 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#     Fitness     Media  Desvio Padrao  RCE
# 0  5.057422  7.638379       2.700887   -
# RCE being applied!  - Generation = 40
# TAMANHO ATUAL DE TODOS INDIVIDUOS 4000
#
#
# Melhor da geração: 26
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 2531           26     31  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#        Fitness     Media  Desvio Padrao  RCE
# 2531  4.819124  5.121338       1.487894   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(88) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 38, 'index': 88, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, -1.6975914085101107, -0.01696012673276047, 2.007792777047566], 'Fitness': 22.659340680459657, 'Media': 5.396432892357341, 'Desvio Padrao': 2.8659709597811958, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 4) = 1 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#     Fitness     Media  Desvio Padrao  RCE
# 0  5.057422  7.638379       2.700887   -
# RCE being applied!  - Generation = 60
# TAMANHO ATUAL DE TODOS INDIVIDUOS 6000
#
#
# Melhor da geração: 49
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 4828           49     28  [0.03878548053419295, 0.048748329301698146, 0....
#
#        Fitness     Media  Desvio Padrao  RCE
# 4828  4.290864  5.243845       3.009226   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(8) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(3) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(6) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(73) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(83) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 52, 'index': 83, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 1.4813581666481626, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -1.3153102094495757, 0.08224094965322404], 'Fitness': 41.774973080593035, 'Media': 5.664818887239238, 'Desvio Padrao': 5.085628337830063, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 10) = 2 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
# 1           19     97  [2.047686851420459, 0.9925989370895953, 0.0652...
#
#      Fitness     Media  Desvio Padrao  RCE
# 0   5.057422  7.638379       2.700887   -
# 1  31.611389  6.130128       4.647723   -
# RCE being applied!  - Generation = 80
# TAMANHO ATUAL DE TODOS INDIVIDUOS 8000
#
#
# Melhor da geração: 49
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 4828           49     28  [0.03878548053419295, 0.048748329301698146, 0....
#
#        Fitness     Media  Desvio Padrao  RCE
# 4828  4.290864  5.243845       3.009226   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(79) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(82) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(70) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(37) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 75, 'index': 37, 'Variaveis de Decisão': [0.03878548053419295, 0.048748329301698146, 1.1700503491569223, -1.3476873837471404, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404], 'Fitness': 27.551068408732974, 'Media': 5.748342779215301, 'Desvio Padrao': 5.5955820803100975, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 15) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
# 1           19     97  [2.047686851420459, 0.9925989370895953, 0.0652...
# 2           26     31  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#      Fitness     Media  Desvio Padrao  RCE
# 0   5.057422  7.638379       2.700887   -
# 1  31.611389  6.130128       4.647723   -
# 2   4.819124  5.121338       1.487894   -
# RCE being applied!  - Generation = 100
# TAMANHO ATUAL DE TODOS INDIVIDUOS 10000
#
#
# Melhor da geração: 99
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 9865           99     65  [-0.035630303594955295, 0.048748329301698146, ...
#
#        Fitness     Media  Desvio Padrao  RCE
# 9865  4.008451  4.749126       3.001847   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(59) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(53) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(1) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 92, 'index': 1, 'Variaveis de Decisão': [1.8206970055147258, 0.3318389321610698, -1.7363409298530383, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -1.0174110439626924, 0.08224094965322404], 'Fitness': 41.64972572984412, 'Media': 5.219065305186676, 'Desvio Padrao': 4.843983282404857, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 19) = 4 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
# 1           19     97  [2.047686851420459, 0.9925989370895953, 0.0652...
# 2           26     31  [0.03878548053419295, 0.9925989370895953, 0.06...
# 3           38     88  [0.03878548053419295, 0.9925989370895953, 0.06...
#
#      Fitness     Media  Desvio Padrao  RCE
# 0   5.057422  7.638379       2.700887   -
# 1  31.611389  6.130128       4.647723   -
# 2   4.819124  5.121338       1.487894   -
# 3  22.659341  5.396433       2.865971   -
# Evolução concluída  - 100%
# =================================================================
#
#
# Todos Individuos Gerados
# =================================================================
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.22277033908879063, 0.9836130644356368, 0.18...
# 1               1      1  [0.8844108760302625, 0.35288064432594046, 0.46...
# 2               1      2  [0.5990838245131679, 0.09971436571590386, 0.84...
# 3               1      3  [0.6758969287034055, 0.8280705518094389, 0.553...
# 4               1      4  [0.3640978209651178, 0.2150147272042071, 0.304...
# ...           ...    ...                                                ...
# 9995          100     95  [0.03878548053419295, 0.048748329301698146, 0....
# 9996          100     96  [0.03878548053419295, 0.048748329301698146, 0....
# 9997          100     97  [0.03878548053419295, 0.048748329301698146, 0....
# 9998          100     98  [0.03878548053419295, 0.048748329301698146, 0....
# 9999          100     99  [0.03878548053419295, 0.048748329301698146, 0....
#
#          Fitness       Media  Desvio Padrao  RCE
# 0     108.536819  101.831987      23.271780   -
# 1     127.404397  101.831987      23.271780   -
# 2     110.713727  101.831987      23.271780   -
# 3     136.206418  101.831987      23.271780   -
# 4     116.692398  101.831987      23.271780   -
# ...          ...         ...            ...  ...
# 9995    4.290864    4.290571       0.122803   -
# 9996    4.290864    4.290571       0.122803   -
# 9997    4.290864    4.290571       0.122803   -
# 9998    4.290864    4.290571       0.122803   -
# 9999    4.290864    4.290571       0.122803   -
#
# [10000 rows x 7 columns]
# -->Conjunto Elite: [{'Generations': 13, 'index': 57, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, 0.037786250677055655, 0.02425113467967499, 0.07181974847878647, 0.0283158166023314, 0.08224094965322404], 'Fitness': 5.057421660134214, 'Media': 7.638378739318174, 'Desvio Padrao': 2.7008872401309993, 'RCE': ' - '}, {'Generations': 19, 'index': 97, 'Variaveis de Decisão': [2.047686851420459, 0.9925989370895953, 0.0652293519464483, -1.5153058463869216, 0.00973253073010194, 0.037786250677055655, 0.02425113467967499, 0.07181974847878647, 0.0283158166023314, 0.08224094965322404], 'Fitness': 31.61138875023194, 'Media': 6.1301283224487175, 'Desvio Padrao': 4.647723060799118, 'RCE': ' - '}, {'Generations': 26, 'index': 31, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404], 'Fitness': 4.819123921769151, 'Media': 5.121338237042357, 'Desvio Padrao': 1.487893741264353, 'RCE': ' - '}, {'Generations': 38, 'index': 88, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, -1.6975914085101107, -0.01696012673276047, 2.007792777047566], 'Fitness': 22.659340680459657, 'Media': 5.396432892357341, 'Desvio Padrao': 2.8659709597811958, 'RCE': ' - '}, {'Generations': 49, 'index': 28, 'Variaveis de Decisão': [0.03878548053419295, 0.048748329301698146, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404], 'Fitness': 4.290863947573403, 'Media': 5.24384497588888, 'Desvio Padrao': 3.0092259966688193, 'RCE': ' - '}, {'Generations': 42, 'index': 8, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 1.1684987151156383, 0.013761913131460357, -1.4129255140686037, -0.02709363935389396, 1.447747519438169, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404], 'Fitness': 52.415401990772, 'Media': 5.2950867024591775, 'Desvio Padrao': 4.735769873169114, 'RCE': ' - '}, {'Generations': 47, 'index': 3, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, -1.4793958887083853, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.30717690743901144, -0.01696012673276047, 0.08224094965322404], 'Fitness': 38.69556113776234, 'Media': 5.464138598135564, 'Desvio Padrao': 4.086848416162668, 'RCE': ' - '}, {'Generations': 47, 'index': 6, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, -1.157716066329941, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404], 'Fitness': 10.564100656132627, 'Media': 5.464138598135564, 'Desvio Padrao': 4.086848416162668, 'RCE': ' - '}, {'Generations': 48, 'index': 73, 'Variaveis de Decisão': [1.8170881961162666, 0.9925989370895953, 0.0652293519464483, -0.6605058448742646, 3.589093243670691, -0.02709363935389396, 0.02425113467967499, 1.3977725687762086, -0.01696012673276047, 0.08224094965322404], 'Fitness': 79.75373047491112, 'Media': 6.246935840813083, 'Desvio Padrao': 8.515029267549075, 'RCE': ' - '}, {'Generations': 52, 'index': 83, 'Variaveis de Decisão': [0.03878548053419295, 0.9925989370895953, 1.4813581666481626, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -1.3153102094495757, 0.08224094965322404], 'Fitness': 41.774973080593035, 'Media': 5.664818887239238, 'Desvio Padrao': 5.085628337830063, 'RCE': ' - '}, {'Generations': 49, 'index': 28, 'Variaveis de Decisão': [0.03878548053419295, 0.048748329301698146, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.024251134679674 ...
#     Generations  index                               Variaveis de Decisão  \
# 8            48     73  [1.8170881961162666, 0.9925989370895953, 0.065...
# 5            42      8  [0.03878548053419295, 0.9925989370895953, 1.16...
# 9            52     83  [0.03878548053419295, 0.9925989370895953, 1.48...
# 18           92      1  [1.8206970055147258, 0.3318389321610698, -1.73...
# 16           85     59  [0.03878548053419295, 0.7318649405575058, 0.06...
# 6            47      3  [0.03878548053419295, 0.9925989370895953, -1.4...
# 11           63     79  [0.03878548053419295, 0.048748329301698146, 0....
# 13           75     70  [0.03878548053419295, 0.048748329301698146, 0....
# 12           63     82  [0.03878548053419295, -1.4016292994978505, -1....
# 1            19     97  [2.047686851420459, 0.9925989370895953, 0.0652...
# 14           75     37  [0.03878548053419295, 0.048748329301698146, 1....
# 17           88     53  [0.03878548053419295, 0.048748329301698146, 0....
# 3            38     88  [0.03878548053419295, 0.9925989370895953, 0.06...
# 7            47      6  [0.03878548053419295, 0.9925989370895953, 0.06...
# 0            13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
# 2            26     31  [0.03878548053419295, 0.9925989370895953, 0.06...
# 4            49     28  [0.03878548053419295, 0.048748329301698146, 0....
# 10           49     28  [0.03878548053419295, 0.048748329301698146, 0....
# 15           99     65  [-0.035630303594955295, 0.048748329301698146, ...
#
#       Fitness     Media  Desvio Padrao  RCE
# 8   79.753730  6.246936       8.515029   -
# 5   52.415402  5.295087       4.735770   -
# 9   41.774973  5.664819       5.085628   -
# 18  41.649726  5.219065       4.843983   -
# 16  39.808339  4.950484       4.104384   -
# 6   38.695561  5.464139       4.086848   -
# 11  35.578174  4.888275       4.152133   -
# 13  32.454781  5.748343       5.595582   -
# 12  32.229175  4.888275       4.152133   -
# 1   31.611389  6.130128       4.647723   -
# 14  27.551068  5.748343       5.595582   -
# 17  24.565103  4.898836       3.397422   -
# 3   22.659341  5.396433       2.865971   -
# 7   10.564101  5.464139       4.086848   -
# 0    5.057422  7.638379       2.700887   -
# 2    4.819124  5.121338       1.487894   -
# 4    4.290864  5.243845       3.009226   -
# 10   4.290864  5.243845       3.009226   -
# 15   4.008451  4.749126       3.001847   -
# (19, 7)
#
# Results RCE
#       Generations  index                               Variaveis de Decisão  \
# 0              13     57  [0.03878548053419295, 0.9925989370895953, 0.06...
# 1              19     97  [2.047686851420459, 0.9925989370895953, 0.0652...
# 2              26     31  [0.03878548053419295, 0.9925989370895953, 0.06...
# 3              38     88  [0.03878548053419295, 0.9925989370895953, 0.06...
# 4              49     28  [0.03878548053419295, 0.048748329301698146, 0....
# ...           ...    ...                                                ...
# 9922          100     22  [0.03878548053419295, 0.048748329301698146, 0....
# 9920          100     20  [0.03878548053419295, 0.048748329301698146, 0....
# 9951          100     51  [0.03878548053419295, 0.048748329301698146, 0....
# 9907          100      7  [-0.035630303594955295, 0.048748329301698146, ...
# 9979          100     79  [0.03878548053419295, 0.048748329301698146, 0....
#
#         Fitness     Media  Desvio Padrao  RCE
# 0      5.057422  7.638379       2.700887  SIM
# 1     31.611389  6.130128       4.647723  SIM
# 2      4.819124  5.121338       1.487894  SIM
# 3     22.659341  5.396433       2.865971  SIM
# 4      4.290864  5.243845       3.009226  SIM
# ...         ...       ...            ...  ...
# 9922   4.290864  4.290571       0.122803  NÃO
# 9920   4.290864  4.290571       0.122803  NÃO
# 9951   4.290864  4.290571       0.122803  NÃO
# 9907   4.008451  4.290571       0.122803  NÃO
# 9979   4.290864  4.290571       0.122803  NÃO
#
# [100 rows x 7 columns]
# VISUALIZANDO OS RESULTADOS
# =================================================================
# Soluções do problema
# =================================================================
#
# Best solution index =  97
#
# Best solution variables =
#  [0.03878548053419295, 0.048748329301698146, 0.0652293519464483, 0.013761913131460357, 0.00973253073010194, -0.02709363935389396, 0.02425113467967499, 0.07181974847878647, -0.01696012673276047, 0.08224094965322404]
#
# Best solution fitness =  4.00845092652421
#
# Ótimo global da função Rastrigin =  1.0820272677847242e-08
#
# Solução ótima global =  [ 1.24126711e-06  2.23209454e-06  4.67041816e-07 -1.79369794e-08
#   2.53052297e-06  6.99603391e-07 -2.59911238e-06  4.71553576e-07
#   1.54112937e-06  5.61716974e-06]
#
# Porcentagem de proximidade da solução em relação ao ótimo global =  -37045747690.91164 %
#
# Distância da solução em relação ao ótimo global = <built-in function abs>
# 100 100 100
# Plotando diversidade dos genes
# Total execution time: 7.6 seconds
