# %% [markdown]
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE
#
# -Sobre a visualização dos dados:
#   + manter o gráfico de convergência (retirando a soma e corrigindo o Best para Max) e os dados associados
#   + apresentar a melhor solução no final - valores das variáveis de decisão e valor da aptidão
#   + incluir tempo de execução total
# - Falta implementar o elitismo simples
# - Falta implementar a repopulação
# - Depois que tudo funcionar :
#   + Armazenar várias execuções do algoritmo em sequencia e extrair média e desvio padrão da melhor solução (ótimo) e dos tempos de execução.

# %% [markdown]
# 1 - O RCE vai descobrir o array com os x indivíduos do offspring que precisam ser copiados.
# 2 - Criar uma população popRCE de x + 1 indivíduos.
# 3 - Copiar o indivíduo elite para o [0] desta população popRCE.
# 4 - Copiar os x indivíduos do offspring cujo índice está no array para o popRCE a partir de [1].
# 5 - Criar uma população popnew com popsize - x - 1 indivíduos (verificar se quando cria a pop no DEAP ele já calcula o fitness).
# 6 - Copiar popRCE para o topo [0] do pop;
# 7 - Copiar popnew para a posição x + 1 do pop;

# %% [markdown]
# ## Interface beta

# %%
import easygui

def show_input_form(default_data):
    """
    Exibe um formulário de entrada com valores padrão e permite edição através de uma lista suspensa.
    
    Args:
        default_data (dict): Dicionário contendo os valores padrão para os campos.
    
    Returns:
        dict: Dicionário contendo os dados preenchidos pelo usuário.
    """
    data_dict = {}

    for field_name, default_value in default_data.items():
        # Verifica se o valor padrão não é uma lista, o que indica um campo de entrada
        if not isinstance(default_value, list):
            # Exibe um input para o campo
            value = easygui.enterbox(f"Digite o valor para '{field_name}':", field_name, default_value)
            data_dict[field_name] = value

    return data_dict

# Define os valores padrão para os campos
default_values = {
    "CROSSOVER": 0.9,
    "TAXA MUTACAO": 0.05,
    "GENERATIONS": 100,
    "POP_SIZE": 100,
    "IND_SIZE": 10,
    "evaluations": 0,
    "num_genes": 5
}

# Chama a função para exibir o formulário de entrada com valores padrão
input_data = show_input_form(default_values)

# Verifica se o formulário foi preenchido e exibe os dados
if input_data is not None:
    print("Dados preenchidos:")
    for key, value in input_data.items():
        print(f"{key}: {value}")
else:
    print("Operação cancelada pelo usuário.")

# Exibe a tela para escolha do tipo de otimização (minimização/máximação)
min_max_choice = easygui.buttonbox("Selecione o tipo de otimização:", "Minimize/Maximize", choices=["Minimize", "Maximize"])
print(f"Tipo de otimização selecionado: {min_max_choice}")

# Exibe a tela para escolha da função objetivo (Rastrigin ou Sphere)
function_choice = easygui.buttonbox("Selecione a função objetivo:", "Função Objetivo", choices=["Rastrigin", "Sphere"])
print(f"Função objetivo selecionada: {function_choice}")
# Out:
# Dados preenchidos:
# CROSSOVER: 0.9
# TAXA MUTACAO: 0.05
# GENERATIONS: 100
# POP_SIZE: 100
# IND_SIZE: 10
# evaluations: 0
# num_genes: 5
# Tipo de otimização selecionado: Minimize
# Função objetivo selecionada: Rastrigin

# %%
from src.models.Setup import Setup
from src.models.DataExploration import DataExploration
from src.models.AlgEvolution import AlgEvolution
import time
from src.backend.pdf_generator import PDFGenerator
import json
import pandas as pd

from IPython.display import display


def load_params(file_path):
    with open(file_path, "r") as file:
        params = json.load(file)
    return params



def main():

    tempo1 = time.time()




    #Setup
    params = load_params("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Iniciação Cientifica - Eng Eletrica UFF/evolution_rce_master/src/db/parameters.json")
    data_visual = DataExploration()
    setup = Setup(params)
    alg = AlgEvolution(setup)
    pop_with_repopulation, logbook_with_repopulation, best_variables = alg.run(RCE=True)
    print("\nEvolução concluída  - 100%")




    # Salvar resultados
    all_df = data_visual.displayDataFrameInfo(alg.allIndividualValuesArray, "\n\nTodos Individuos Gerados")
    print("\n\n-->Conjunto Elite:", alg.pop_RCE)
    best_df = pd.DataFrame(alg.pop_RCE)
    display(best_df.sort_values(by = "Fitness" ,ascending=False))
    print(best_df.shape)

    print("\nResults RCE")
    alg.combinar_aleatoriamente()
    #data_visual.plot_grafico_barras(setup.NGEN,best_df["Fitness"])


    

    
    # Visualização dos resultados
    print("\n\nVISUALIZANDO OS RESULTADOS")
    #TODO data_visual.displayDataFrameInfo(alg.best_individual_array, "Best 100 variables with repopulation")
    data_visual.visualize(
        logbook_with_repopulation, pop_with_repopulation, repopulation=True
    )
    data_visual.statistics_per_generation_df(logbook_with_repopulation)
    data_visual.plot_diversidade_genes()




    tempo2 = time.time()
    print(f"Total execution time: {round(tempo2-tempo1,2)} seconds")


main()
# Out:
# RCE being applied!  - Generation = 20
# TAMANHO ATUAL DE TODOS INDIVIDUOS 2000
#
#
# Melhor da geração: 11
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 1013           11     13  [0.011794344220784181, 0.06923407126196568, 0....
#
#         Fitness      Media  Desvio Padrao  RCE
# 1013  10.886438  15.098167       6.009977   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(48) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(66) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(15) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(30) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(18) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(78) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(47) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 17, 'index': 47, 'Variaveis de Decisão': [0.011794344220784181, 0.06923407126196568, 0.9082309032500678, 0.009350216755241059, 1.347377616554163, 0.0427192769974476, -1.3139517312209552, 0.01269034019976878, 0.9905639432009514, 0.1656943430068999], 'Fitness': 42.98460372534963, 'Media': 11.821335755257017, 'Desvio Padrao': 4.689706766960884, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 8) = 2 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1            7     48  [0.20608006709130589, -2.340856316520127, 1.64...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0  10.886438  15.098167       6.009977   -
# 1  78.923711  29.500692      10.020801   -
# RCE being applied!  - Generation = 40
# TAMANHO ATUAL DE TODOS INDIVIDUOS 4000
#
#
# Melhor da geração: 28
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 2700           28      0  [0.011794344220784181, 0.06923407126196568, 1....
#
#        Fitness     Media  Desvio Padrao  RCE
# 2700  6.402675  9.829477       1.661687   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(37) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(69) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(17) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(73) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(29) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(96) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 39, 'index': 96, 'Variaveis de Decisão': [0.011794344220784181, 0.06923407126196568, 1.031135006676745, 0.009350216755241059, 0.02009330838536405, 0.0427192769974476, 3.1942900988612384, 0.01269034019976878, 0.9905639432009514, 2.0773741385704545], 'Fitness': 25.953956624770356, 'Media': 8.434666584559992, 'Desvio Padrao': 7.400669160096507, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 15) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1            7     48  [0.20608006709130589, -2.340856316520127, 1.64...
# 2            9     66  [0.011794344220784181, 0.996597380422995, 0.90...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0  10.886438  15.098167       6.009977   -
# 1  78.923711  29.500692      10.020801   -
# 2  37.296599  18.529386       4.858719   -
# RCE being applied!  - Generation = 60
# TAMANHO ATUAL DE TODOS INDIVIDUOS 6000
#
#
# Melhor da geração: 46
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 4528           46     28  [0.011794344220784181, 0.06923407126196568, 1....
#
#        Fitness     Media  Desvio Padrao  RCE
# 4528  6.401477  6.835198       4.303675   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(23) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(44) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(63) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(41) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 49, 'index': 41, 'Variaveis de Decisão': [0.011794344220784181, 0.06923407126196568, 2.0439029231918173, 0.009350216755241059, 0.02009330838536405, 0.0427192769974476, 0.5284352951538411, 0.01269034019976878, 0.9905639432009514, 0.09330711504460051], 'Fitness': 28.805916355808385, 'Media': 7.191926805572609, 'Desvio Padrao': 4.225149306083194, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 20) = 4 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1            7     48  [0.20608006709130589, -2.340856316520127, 1.64...
# 2            9     66  [0.011794344220784181, 0.996597380422995, 0.90...
# 3           11     15  [1.598586621800457, -0.23896979505916893, 0.12...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0  10.886438  15.098167       6.009977   -
# 1  78.923711  29.500692      10.020801   -
# 2  37.296599  18.529386       4.858719   -
# 3  63.957201  15.098167       6.009977   -
# RCE being applied!  - Generation = 80
# TAMANHO ATUAL DE TODOS INDIVIDUOS 8000
#
#
# Melhor da geração: 80
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 7915           80     15  [0.011794344220784181, 0.06923407126196568, -0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 7915  4.694217  5.740822       2.961563   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(6) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(25) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(65) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 77, 'index': 65, 'Variaveis de Decisão': [2.1058014647194163, 0.06923407126196568, -0.23764977640609364, -1.7600180720377543, 0.02009330838536405, 0.0427192769974476, 0.0722643231463227, -0.6325278462927587, 0.9905639432009514, 0.09330711504460051], 'Fitness': 50.51446747516993, 'Media': 6.764398798514592, 'Desvio Padrao': 4.824717305126191, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 24) = 5 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1            7     48  [0.20608006709130589, -2.340856316520127, 1.64...
# 2            9     66  [0.011794344220784181, 0.996597380422995, 0.90...
# 3           11     15  [1.598586621800457, -0.23896979505916893, 0.12...
# 4           12     30  [0.011794344220784181, -0.9494870325755407, 0....
#
#      Fitness      Media  Desvio Padrao  RCE
# 0  10.886438  15.098167       6.009977   -
# 1  78.923711  29.500692      10.020801   -
# 2  37.296599  18.529386       4.858719   -
# 3  63.957201  15.098167       6.009977   -
# 4  27.642003  13.427985       3.219800   -
# RCE being applied!  - Generation = 100
# TAMANHO ATUAL DE TODOS INDIVIDUOS 10000
#
#
# Melhor da geração: 80
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 7915           80     15  [0.011794344220784181, 0.06923407126196568, -0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 7915  4.694217  5.740822       2.961563   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(79) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 84, 'index': 79, 'Variaveis de Decisão': [0.011794344220784181, 0.06923407126196568, -0.9847153882173771, -0.009021388523671355, 0.02009330838536405, 0.0427192769974476, 0.4924513626522832, -1.2404559298642077, -0.06553012110962864, -0.43327138820725003], 'Fitness': 53.7677998779141, 'Media': 5.637782800720218, 'Desvio Padrao': 5.440805884148655, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 26) = 6 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1            7     48  [0.20608006709130589, -2.340856316520127, 1.64...
# 2            9     66  [0.011794344220784181, 0.996597380422995, 0.90...
# 3           11     15  [1.598586621800457, -0.23896979505916893, 0.12...
# 4           12     30  [0.011794344220784181, -0.9494870325755407, 0....
# 5           14     18  [0.011794344220784181, 0.06923407126196568, 1....
#
#      Fitness      Media  Desvio Padrao  RCE
# 0  10.886438  15.098167       6.009977   -
# 1  78.923711  29.500692      10.020801   -
# 2  37.296599  18.529386       4.858719   -
# 3  63.957201  15.098167       6.009977   -
# 4  27.642003  13.427985       3.219800   -
# 5  25.827399  11.729909       2.373958   -
# Evolução concluída  - 100%
# =================================================================
#
#
# Todos Individuos Gerados
# =================================================================
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.653905696825203, 0.6285099882111834, 0.0502...
# 1               1      1  [0.43545748682539764, 0.04376956969539947, 0.6...
# 2               1      2  [0.6103372410770739, 0.7157451124873307, 0.384...
# 3               1      3  [0.9078087651311488, 0.6293483491437422, 0.644...
# 4               1      4  [0.5217312427453857, 0.7172646894191631, 0.120...
# ...           ...    ...                                                ...
# 9995          100     95  [0.011794344220784181, 0.06923407126196568, -0...
# 9996          100     96  [0.011794344220784181, 0.06923407126196568, -0...
# 9997          100     97  [0.011794344220784181, 0.06923407126196568, -0...
# 9998          100     98  [0.011794344220784181, 0.06923407126196568, -0...
# 9999          100     99  [0.011794344220784181, 0.06923407126196568, -0...
# 3   63.957201  15.098167       6.009977   -
# 6   59.446032  12.004925       6.061709   -
# 25  53.767800   5.637783       5.440806   -
# 23  50.514467   6.764399       4.824717   -
# 7   42.984604  11.821336       4.689707   -
# 17  42.904840   7.224917       4.594395   -
# 9   42.182506  10.522143       5.172363   -
# 2   37.296599  18.529386       4.858719   -
# 18  36.390074   7.191927       4.225149   -
# 10  33.978261   9.284785       2.660435   -
# 12  31.573231   8.434667       7.400669   -
# 21  30.760543   6.914410       3.206028   -
# 22  29.041365   6.406316       2.275611   -
# 19  28.805916   7.191927       4.225149   -
# 4   27.642003  13.427985       3.219800   -
# 13  27.112999   8.434667       7.400669   -
# 14  25.953957   8.434667       7.400669   -
# 5   25.827399  11.729909       2.373958   -
# 16  17.398955   6.908576       2.555593   -
# 0   10.886438  15.098167       6.009977   -
# 8    6.402675   9.829477       1.661687   -
# 15   6.401477   6.835198       4.303675   -
# 20   4.694217   5.740822       2.961563   -
# 24   4.694217   5.740822       2.961563   -
# (26, 7)
#
# Results RCE
#       Generations  index                               Variaveis de Decisão  \
# 0              11     13  [0.011794344220784181, 0.06923407126196568, 0....
# 1               7     48  [0.20608006709130589, -2.340856316520127, 1.64...
# 2               9     66  [0.011794344220784181, 0.996597380422995, 0.90...
# 3              11     15  [1.598586621800457, -0.23896979505916893, 0.12...
# 4              12     30  [0.011794344220784181, -0.9494870325755407, 0....
# ...           ...    ...                                                ...
# 9921          100     21  [0.011794344220784181, 0.06923407126196568, -0...
# 9975          100     75  [0.011794344220784181, 0.06923407126196568, -0...
# 9942          100     42  [0.011794344220784181, 0.06923407126196568, -0...
# 9928          100     28  [0.011794344220784181, 0.06923407126196568, -0...
# 9987          100     87  [0.011794344220784181, 0.06923407126196568, -0...
#
#         Fitness      Media  Desvio Padrao  RCE
# 0     10.886438  15.098167       6.009977  SIM
# 1     78.923711  29.500692      10.020801  SIM
# 2     37.296599  18.529386       4.858719  SIM
# 3     63.957201  15.098167       6.009977  SIM
# 4     27.642003  13.427985       3.219800  SIM
# ...         ...        ...            ...  ...
# 9921   4.694217   5.601844       5.040972  NÃO
# 9975   4.694217   5.601844       5.040972  NÃO
# 9942   4.694217   5.601844       5.040972  NÃO
# 9928   4.694217   5.601844       5.040972  NÃO
# 9987   4.694217   5.601844       5.040972  NÃO
#
# [100 rows x 7 columns]
# VISUALIZANDO OS RESULTADOS
# =================================================================
# Soluções do problema
# =================================================================
#
# Best solution index =  78
#
# Best solution variables =
#  [0.011794344220784181, 0.06923407126196568, -0.9847153882173771, -0.009021388523671355, 0.02009330838536405, 0.0427192769974476, 0.0722643231463227, 0.01269034019976878, -0.06553012110962864, 0.04321931149019442]
#
# Best solution fitness =  4.694216527272189
#
# Ótimo global da função Rastrigin =  0.9950382177102881
#
# Solução ótima global =  [-2.71365404e-04  2.38659195e-04 -9.94877169e-01 -1.52882178e-04
#  -1.79156233e-04  4.47274589e-04 -2.37730091e-05  1.83241020e-05
#   7.31450604e-05 -2.07740600e-06]
#
# Porcentagem de proximidade da solução em relação ao ótimo global =  -371.7624352232611 %
#
# Distância da solução em relação ao ótimo global = <built-in function abs>
# 100 100 100
# Total execution time: 4.37 seconds
