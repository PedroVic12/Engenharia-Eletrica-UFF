# %% [markdown]
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE
#
# -Sobre a visualização dos dados:
#   + manter o gráfico de convergência (retirando a soma e corrigindo o Best para Max) e os dados associados
#   + apresentar a melhor solução no final - valores das variáveis de decisão e valor da aptidão
#   + incluir tempo de execução total
# - Falta implementar o elitismo simples
# - Falta implementar a repopulação
# - Depois que tudo funcionar :
#   + Armazenar várias execuções do algoritmo em sequencia e extrair média e desvio padrão da melhor solução (ótimo) e dos tempos de execução.

# %% [markdown]
# 1 - O RCE vai descobrir o array com os x indivíduos do offspring que precisam ser copiados.
# 2 - Criar uma população popRCE de x + 1 indivíduos.
# 3 - Copiar o indivíduo elite para o [0] desta população popRCE.
# 4 - Copiar os x indivíduos do offspring cujo índice está no array para o popRCE a partir de [1].
# 5 - Criar uma população popnew com popsize - x - 1 indivíduos (verificar se quando cria a pop no DEAP ele já calcula o fitness).
# 6 - Copiar popRCE para o topo [0] do pop;
# 7 - Copiar popnew para a posição x + 1 do pop;

# %% [markdown]
# ## Interface beta

# %%
import easygui

def show_input_form(default_data):
    """
    Exibe um formulário de entrada com valores padrão e permite edição através de uma lista suspensa.
    
    Args:
        default_data (dict): Dicionário contendo os valores padrão para os campos.
    
    Returns:
        dict: Dicionário contendo os dados preenchidos pelo usuário.
    """
    data_dict = {}

    for field_name, default_value in default_data.items():
        # Verifica se o valor padrão não é uma lista, o que indica um campo de entrada
        if not isinstance(default_value, list):
            # Exibe um input para o campo
            value = easygui.enterbox(f"Digite o valor para '{field_name}':", field_name, default_value)
            data_dict[field_name] = value

    return data_dict

# Define os valores padrão para os campos
default_values = {
    "CROSSOVER": 0.9,
    "TAXA MUTACAO": 0.05,
    "GENERATIONS": 100,
    "POP_SIZE": 100,
    "IND_SIZE": 10,
    "evaluations": 0,
    "num_genes": 5
}

# Chama a função para exibir o formulário de entrada com valores padrão
input_data = show_input_form(default_values)

# Verifica se o formulário foi preenchido e exibe os dados
if input_data is not None:
    print("Dados preenchidos:")
    for key, value in input_data.items():
        print(f"{key}: {value}")
else:
    print("Operação cancelada pelo usuário.")

# Exibe a tela para escolha do tipo de otimização (minimização/máximação)
min_max_choice = easygui.buttonbox("Selecione o tipo de otimização:", "Minimize/Maximize", choices=["Minimize", "Maximize"])
print(f"Tipo de otimização selecionado: {min_max_choice}")

# Exibe a tela para escolha da função objetivo (Rastrigin ou Sphere)
function_choice = easygui.buttonbox("Selecione a função objetivo:", "Função Objetivo", choices=["Rastrigin", "Sphere"])
print(f"Função objetivo selecionada: {function_choice}")
# Out:
# Dados preenchidos:
# CROSSOVER: 0.9
# TAXA MUTACAO: 0.05
# GENERATIONS: 100
# POP_SIZE: 100
# IND_SIZE: 10
# evaluations: 0
# num_genes: 5
# Tipo de otimização selecionado: Minimize
# Função objetivo selecionada: Rastrigin

# %%
from src.models.Setup import Setup
from src.models.DataExploration import DataExploration
from src.models.AlgEvolution import AlgEvolution
import time
from src.backend.pdf_generator import PDFGenerator
import json
import pandas as pd

from IPython.display import display


def load_params(file_path):
    with open(file_path, "r") as file:
        params = json.load(file)
    return params



def main():
    tempo1 = time.time()




    #Setup
    params = load_params("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Iniciação Cientifica - Eng Eletrica UFF/evolution_rce_master/src/db/parameters.json")
    data_visual = DataExploration()
    setup = Setup(params)
    alg = AlgEvolution(setup)
    pop_with_repopulation, logbook_with_repopulation, best_variables = alg.run(RCE=True)
    print("\nEvolução concluída  - 100%")




    # Salvar resultados
    all_df = data_visual.displayDataFrameInfo(alg.allIndividualValuesArray, "\n\nTodos Individuos Gerados")
    print("\n\n-->Conjunto Elite:", alg.pop_RCE)
    best_df = pd.DataFrame(alg.pop_RCE)
    display(best_df.sort_values(by = "Fitness" ,ascending=False))
    print(best_df.shape)

    print("\nResults RCE")
    alg.combinar_aleatoriamente()
    #data_visual.plot_grafico_barras(setup.NGEN,best_df["Fitness"])


    

    
    # Visualização dos resultados
    print("\n\nVISUALIZANDO OS RESULTADOS")
    #TODO data_visual.displayDataFrameInfo(alg.best_individual_array, "Best 100 variables with repopulation")
    data_visual.visualize(
        logbook_with_repopulation, pop_with_repopulation, repopulation=True
    )
    data_visual.statistics_per_generation_df(logbook_with_repopulation)
    data_visual.plot_diversidade_genes(pop_with_repopulation)






















    tempo2 = time.time()
    print(f"Total execution time: {round(tempo2-tempo1,2)} seconds")
main()
# Out:
# RCE being applied!  - Generation = 20
# TAMANHO ATUAL DE TODOS INDIVIDUOS 2000
#
#
# Melhor da geração: 15
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 1435           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 1435  4.683355  8.498411       6.511035   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(18) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(87) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(94) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(51) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(92) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(46) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(90) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 17, 'index': 90, 'Variaveis de Decisão': [0.03796344156536846, 2.5414580480634696, 0.039143895802707274, 0.9810323003622804, 0.05126991044511675, 2.3802009876555017, 0.012937106143058319, 0.022416171257737094, 0.10009825450304688, 0.03812000701705964], 'Fitness': 53.565870890485854, 'Media': 7.24709244991363, 'Desvio Padrao': 7.45935802142937, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 8) = 2 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1            6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   4.683355   8.498411       6.511035   -
# 1  59.181729  30.695704       7.098721   -
# RCE being applied!  - Generation = 40
# TAMANHO ATUAL DE TODOS INDIVIDUOS 4000
#
#
# Melhor da geração: 37
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 3696           37     96  [0.03796344156536846, 0.03107786380941524, -0....
#
#       Fitness     Media  Desvio Padrao  RCE
# 3696  3.92743  5.201381       4.896343   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(57) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(29) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 36, 'index': 29, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, -0.01641896656748633, 0.9810323003622804, 0.05126991044511675, 0.007716004987624814, 0.012937106143058319, 0.022416171257737094, 1.639795935989113, 0.03812000701705964], 'Fitness': 21.583892367745783, 'Media': 4.779524848922057, 'Desvio Padrao': 2.322896870142833, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 11) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1            6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 2            9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   4.683355   8.498411       6.511035   -
# 1  59.181729  30.695704       7.098721   -
# 2  34.683638  18.210021       4.366426   -
# RCE being applied!  - Generation = 60
# TAMANHO ATUAL DE TODOS INDIVIDUOS 6000
#
#
# Melhor da geração: 56
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 5510           56     10  [0.03796344156536846, 0.028606495085877252, -0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 5510  3.898337  4.895139        5.05313   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(35) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 52, 'index': 35, 'Variaveis de Decisão': [0.03796344156536846, 0.33567653840273076, -0.000176290133423955, 0.9810323003622804, 0.01790766831279276, -1.731235995823989, 2.207966924690249, 0.3543938682918125, 0.10009825450304688, 0.03812000701705964], 'Fitness': 61.494186731193, 'Media': 4.672631984826417, 'Desvio Padrao': 5.954677624892774, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 13) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1            6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 2            9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   4.683355   8.498411       6.511035   -
# 1  59.181729  30.695704       7.098721   -
# 2  34.683638  18.210021       4.366426   -
# RCE being applied!  - Generation = 80
# TAMANHO ATUAL DE TODOS INDIVIDUOS 8000
#
#
# Melhor da geração: 79
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 7885           79     85  [0.03796344156536846, 0.028606495085877252, -0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 7885  1.976017  4.592181       4.176345   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Nenhum indivíduo atende aos critérios.
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 14) = 3 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1            6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 2            9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   4.683355   8.498411       6.511035   -
# 1  59.181729  30.695704       7.098721   -
# 2  34.683638  18.210021       4.366426   -
# RCE being applied!  - Generation = 100
# TAMANHO ATUAL DE TODOS INDIVIDUOS 10000
#
#
# Melhor da geração: 79
# Name: Generations, dtype: int64
#       Generations  index                               Variaveis de Decisão  \
# 7885           79     85  [0.03796344156536846, 0.028606495085877252, -0...
#
#        Fitness     Media  Desvio Padrao  RCE
# 7885  1.976017  4.592181       4.176345   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(50) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(23) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 90, 'index': 23, 'Variaveis de Decisão': [0.03796344156536846, 1.3006116446294411, -0.000176290133423955, 0.9810323003622804, 0.3127144981140563, 1.0717132529752642, 0.012937106143058319, 0.022416171257737094, -0.0024182934873307055, 0.03812000701705964], 'Fitness': 32.640753576742924, 'Media': 2.289925056749959, 'Desvio Padrao': 3.0511955089049776, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 17) = 4 | random (80% de 100)= 80.0
#
#
# Candidatos Conjunto Elite
#    Generations  index                               Variaveis de Decisão  \
# 0           15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1            6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 2            9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
# 3            9     94  [1.16091216345849, 0.03107786380941524, 0.9505...
#
#      Fitness      Media  Desvio Padrao  RCE
# 0   4.683355   8.498411       6.511035   -
# 1  59.181729  30.695704       7.098721   -
# 2  34.683638  18.210021       4.366426   -
# 3  29.150687  18.210021       4.366426   -
# Evolução concluída  - 100%
# =================================================================
#
#
# Todos Individuos Gerados
# =================================================================
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.8352696678785998, 0.13182926142372964, 0.91...
# 1               1      1  [0.1884916082013387, 0.9452201007899387, 0.212...
# 2               1      2  [0.6968563175984828, 0.9217354858273513, 0.451...
# 3               1      3  [0.8684022429660445, 0.9361965112681969, 0.376...
# 4               1      4  [0.7647638643889029, 0.10557209074939145, 0.68...
# ...           ...    ...                                                ...
# 9995          100     95  [0.03796344156536846, 0.028606495085877252, -0...
# 9996          100     96  [0.03796344156536846, 0.028606495085877252, -0...
# 9997          100     97  [0.03796344156536846, 0.028606495085877252, -0...
# 9998          100     98  [0.03796344156536846, 0.028606495085877252, -0...
# 9999          100     99  [0.03796344156536846, 0.028606495085877252, -0...
#
#          Fitness      Media  Desvio Padrao  RCE
# 0      85.222167  99.736555      20.333224   -
# 1     108.640706  99.736555      20.333224   -
# 2     120.035038  99.736555      20.333224   -
# 3     106.095819  99.736555      20.333224   -
# 4     102.561177  99.736555      20.333224   -
# ...          ...        ...            ...  ...
# 9995    1.976017   2.521036       3.066732   -
# 9996    1.976017   2.521036       3.066732   -
# 9997    1.976017   2.521036       3.066732   -
# 9998    1.976017   2.521036       3.066732   -
# 9999    1.976017   2.521036       3.066732   -
#
# [10000 rows x 7 columns]
# -->Conjunto Elite: [{'Generations': 15, 'index': 35, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, 0.039143895802707274, 0.9810323003622804, 0.05126991044511675, 0.007716004987624814, 0.012937106143058319, 0.022416171257737094, 0.10009825450304688, 0.03812000701705964], 'Fitness': 4.683355445975906, 'Media': 8.498410808869533, 'Desvio Padrao': 6.511035283830963, 'RCE': ' - '}, {'Generations': 6, 'index': 18, 'Variaveis de Decisão': [0.7081948786274729, 0.13182926142372964, 0.9226008468509163, 0.9806201006449939, 0.9305950674174425, 0.9779857201083689, 0.9779944528593586, 1.6101734025064773, -0.3310094931636599, 0.05536432652170531], 'Fitness': 59.18172881018784, 'Media': 30.69570356400392, 'Desvio Padrao': 7.098720869009883, 'RCE': ' - '}, {'Generations': 9, 'index': 87, 'Variaveis de Decisão': [0.15532524943721582, 0.03107786380941524, 0.9505681041237747, 0.9806201006449939, -0.4117026629970785, 0.9779857201083689, 0.012937106143058319, 0.9345509829690607, 0.8659251488995159, 0.9194280197361134], 'Fitness': 34.68363818939978, 'Media': 18.210021381503335, 'Desvio Padrao': 4.366425947040886, 'RCE': ' - '}, {'Generations': 9, 'index': 94, 'Variaveis de Decisão': [1.16091216345849, 0.03107786380941524, 0.9505681041237747, 1.826742962894738, 0.9305950674174425, -0.8750190555770446, 0.9779944528593586, 0.022416171257737094, 0.8659251488995159, 0.9194280197361134], 'Fitness': 29.1506872158365, 'Media': 18.210021381503335, 'Desvio Padrao': 4.366425947040886, 'RCE': ' - '}, {'Generations': 11, 'index': 51, 'Variaveis de Decisão': [0.9675361191363488, 1.2764958433309785, 0.039143895802707274, 0.9526572721308697, 0.05126991044511675, 0.9779857201083689, 1.4641378595327383, 0.10609575679327521, 0.8659251488995159, 0.03812000701705964], 'Fitness': 46.07129655784884, 'Media': 12.558868487776387, 'Desvio Padrao': 4.480964710571422, 'RCE': ' - '}, {'Generations': 15, 'index': 92, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, 0.039143895802707274, 2.5513795294877313, 0.9801540750828618, 2.8203728439206737, 0.012937106143058319, 1.4744898012394854, 0.8964786215064969, 0.03812000701705964], 'Fitness': 66.69645520648899, 'Media': 8.498410808869533, 'Desvio Padrao': 6.511035283830963, 'RCE': ' - '}, {'Generations': 16, 'index': 46, 'Variaveis de Decisão': [0.9675361191363488, 0.03107786380941524, 0.039143895802707274, 2.1907789662737316, 0.9801540750828618, 0.9779857201083689, 0.012937106143058319, -1.2070083030751477, -0.519987809857564, 0.03812000701705964], 'Fitness': 44.19113050677697, 'Media': 7.386074883364554, 'Desvio Padrao': 4.967152509271971, 'RCE': ' - '}, {'Generations': 17, 'index': 90, 'Variaveis de Decisão': [0.03796344156536846, 2.5414580480634696, 0.039143895802707274, 0.9810323003622804, 0.05126991044511675, 2.3802009876555017, 0.012937106143058319, 0.022416171257737094, 0.10009825450304688, 0.03812000701705964], 'Fitness': 53.565870890485854, 'Media': 7.24709244991363, 'Desvio Padrao': 7.45935802142937, 'RCE': ' - '}, {'Generations': 37, 'index': 96, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, -0.000176290133423955, 0.9810323003622804, 0.01790766831279276, 0.007716004987624814, 0.012937106143058319, 0.022416171257737094, 0.10009825450304688, 0.03812000701705964], 'Fitness': 3.9274298514266945, 'Media': 5.2013812611119965, 'Desvio Padrao': 4.896342779903565, 'RCE': ' - '}, {'Generations': 27, 'index': 57, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, 0.039143895802707274, 0.9810323003622804, -1.5205030387408467, -2.05847197568297, 0.012937106143058319, 0.022416171257737094, -0.49313010403050106, 0.03812000701705964], 'Fitness': 49.59859977466171, 'Media': 5.619052841067093, 'Desvio Padrao': 5.121718481509737, 'RCE': ' - '}, {'Generations': 36, 'index': 29, 'Variaveis de Decisão': [0.03796344156536846, 0.03107786380941524, -0.01641896656748633, 0.9810323003622804, 0.05126991044511675, 0.007716004987624814, 0.012937106143058319, 0.022416171257737 ...
#     Generations  index                               Variaveis de Decisão  \
# 5            15     92  [0.03796344156536846, 0.03107786380941524, 0.0...
# 12           52     35  [0.03796344156536846, 0.33567653840273076, -0....
# 1             6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 7            17     90  [0.03796344156536846, 2.5414580480634696, 0.03...
# 9            27     57  [0.03796344156536846, 0.03107786380941524, 0.0...
# 4            11     51  [0.9675361191363488, 1.2764958433309785, 0.039...
# 6            16     46  [0.9675361191363488, 0.03107786380941524, 0.03...
# 2             9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
# 16           90     23  [0.03796344156536846, 1.3006116446294411, -0.0...
# 15           87     50  [1.1725972999201497, -0.6295516927605912, -0.0...
# 3             9     94  [1.16091216345849, 0.03107786380941524, 0.9505...
# 10           36     29  [0.03796344156536846, 0.03107786380941524, -0....
# 0            15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 8            37     96  [0.03796344156536846, 0.03107786380941524, -0....
# 11           56     10  [0.03796344156536846, 0.028606495085877252, -0...
# 13           79     85  [0.03796344156536846, 0.028606495085877252, -0...
# 14           79     85  [0.03796344156536846, 0.028606495085877252, -0...
#
#       Fitness      Media  Desvio Padrao  RCE
# 5   66.696455   8.498411       6.511035   -
# 12  61.494187   4.672632       5.954678   -
# 1   59.181729  30.695704       7.098721   -
# 7   53.565871   7.247092       7.459358   -
# 9   49.598600   5.619053       5.121718   -
# 4   46.071297  12.558868       4.480965   -
# 6   44.191131   7.386075       4.967153   -
# 2   34.683638  18.210021       4.366426   -
# 16  32.640754   2.289925       3.051196   -
# 15  32.545965   2.785078       4.301144   -
# 3   29.150687  18.210021       4.366426   -
# 10  21.583892   4.779525       2.322897   -
# 0    4.683355   8.498411       6.511035   -
# 8    3.927430   5.201381       4.896343   -
# 11   3.898337   4.895139       5.053130   -
# 13   1.976017   4.592181       4.176345   -
# 14   1.976017   4.592181       4.176345   -
# (17, 7)
#
# Results RCE
#       Generations  index                               Variaveis de Decisão  \
# 0              15     35  [0.03796344156536846, 0.03107786380941524, 0.0...
# 1               6     18  [0.7081948786274729, 0.13182926142372964, 0.92...
# 2               9     87  [0.15532524943721582, 0.03107786380941524, 0.9...
# 3               9     94  [1.16091216345849, 0.03107786380941524, 0.9505...
# 4              11     51  [0.9675361191363488, 1.2764958433309785, 0.039...
# ...           ...    ...                                                ...
# 9953          100     53  [0.03796344156536846, 0.028606495085877252, -0...
# 9948          100     48  [0.03796344156536846, 0.028606495085877252, -0...
# 9944          100     44  [0.03796344156536846, 0.028606495085877252, -0...
# 9914          100     14  [0.03796344156536846, 0.028606495085877252, -0...
# 9987          100     87  [0.03796344156536846, 0.028606495085877252, -0...
#
#         Fitness      Media  Desvio Padrao  RCE
# 0      4.683355   8.498411       6.511035  SIM
# 1     59.181729  30.695704       7.098721  SIM
# 2     34.683638  18.210021       4.366426  SIM
# 3     29.150687  18.210021       4.366426  SIM
# 4     46.071297  12.558868       4.480965  SIM
# ...         ...        ...            ...  ...
# 9953   1.976017   2.521036       3.066732  NÃO
# 9948   1.976017   2.521036       3.066732  NÃO
# 9944   1.976017   2.521036       3.066732  NÃO
# 9914   1.976017   2.521036       3.066732  NÃO
# 9987   1.976017   2.521036       3.066732  NÃO
#
# [100 rows x 7 columns]
# VISUALIZANDO OS RESULTADOS
# =================================================================
# Soluções do problema
# =================================================================
#
# Best solution index =  77
#
# Best solution variables =
#  [0.03796344156536846, 0.028606495085877252, -0.000176290133423955, 0.9810323003622804, 0.01790766831279276, 0.007716004987624814, 0.012937106143058319, 0.022416171257737094, -0.0024182934873307055, 0.03812000701705964]
#
# Best solution fitness =  1.9760174538584536
#
# Ótimo global da função Rastrigin =  0.9949591435545813
#
# Solução ótima global =  [ 4.69892372e-07 -1.17167649e-08 -2.08311874e-05  9.94958087e-01
#   4.86529220e-07  5.13324386e-08  8.07818012e-07 -4.16914916e-07
#   4.87542375e-07  2.10064880e-07]
#
# Porcentagem de proximidade da solução em relação ao ótimo global =  -98.60287396314116 %
#
# Distância da solução em relação ao ótimo global = <built-in function abs>
# 100 100 100
# Plotando diversidade dos genes
# Total execution time: 8.21 seconds
