# %% [markdown]
# 1 - O RCE vai descobrir o array com os x indivíduos do offspring que precisam ser copiados.
# 2 - Criar uma população popRCE de x + 1 indivíduos.
# 3 - Copiar o indivíduo elite para o [0] desta população popRCE.
# 4 - Copiar os x indivíduos do offspring cujo índice está no array para o popRCE a partir de [1].
# 5 - Criar uma população popnew com popsize - x - 1 indivíduos (verificar se quando cria a pop no DEAP ele já calcula o fitness).
# 6 - Copiar popRCE para o topo [0] do pop;
# 7 - Copiar popnew para a posição x + 1 do pop;

# %% [markdown]
# ---
#
# 5ª Reunião (Remota)
# -Sobre a visualização dos dados:
#   + manter o gráfico de convergência (retirando a soma e corrigindo o Best para Max) e os dados associados
#   + apresentar a melhor solução no final - valores das variáveis de decisão e valor da aptidão
#   + incluir tempo de execução total
# - Falta implementar o elitismo simples
#
# 6ª Reunião (Remota)
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE
#
# 7ª Reunião (Remota)
# - resolver pendências das últimas reuniões
# - funcionar o RCE (em 3 etapas)
# - interface beta para todos os parâmetros do AE

# %% [markdown]
# ## Interface beta

# %%
import easygui

def show_input_form(default_data):
    """
    Exibe um formulário de entrada com valores padrão e permite edição através de uma lista suspensa.
    
    Args:
        default_data (dict): Dicionário contendo os valores padrão para os campos.
    
    Returns:
        dict: Dicionário contendo os dados preenchidos pelo usuário.
    """
    data_dict = {}

    for field_name, default_value in default_data.items():
        # Verifica se o valor padrão não é uma lista, o que indica um campo de entrada
        if not isinstance(default_value, list):
            # Exibe um input para o campo
            value = easygui.enterbox(f"Digite o valor para '{field_name}':", field_name, default_value)
            data_dict[field_name] = value

    return data_dict

# Define os valores padrão para os campos
default_values = {
    "CROSSOVER": 0.9,
    "TAXA MUTACAO": 0.05,
    "GENERATIONS": 100,
    "POP_SIZE": 100,
    "IND_SIZE": 10,
    "evaluations": 0,
    "num_genes": 5
}

# Chama a função para exibir o formulário de entrada com valores padrão
input_data = show_input_form(default_values)

# Verifica se o formulário foi preenchido e exibe os dados
if input_data is not None:
    print("Dados preenchidos:")
    for key, value in input_data.items():
        print(f"{key}: {value}")
else:
    print("Operação cancelada pelo usuário.")

# Exibe a tela para escolha do tipo de otimização (minimização/máximação)
min_max_choice = easygui.buttonbox("Selecione o tipo de otimização:", "Minimize/Maximize", choices=["Minimize", "Maximize"])
print(f"Tipo de otimização selecionado: {min_max_choice}")

# Exibe a tela para escolha da função objetivo (Rastrigin ou Sphere)
function_choice = easygui.buttonbox("Selecione a função objetivo:", "Função Objetivo", choices=["Rastrigin", "Sphere"])
print(f"Função objetivo selecionada: {function_choice}")
# Out:
# Dados preenchidos:
# CROSSOVER: 0.9
# TAXA MUTACAO: 0.05
# GENERATIONS: 100
# POP_SIZE: 100
# IND_SIZE: 10
# evaluations: 0
# num_genes: 5
# Tipo de otimização selecionado: Minimize
# Função objetivo selecionada: Rastrigin

# %% [markdown]
# ## Evolution

# %%
from src.models.Setup import Setup
from src.models.DataExploration import DataExploration
from src.models.AlgEvolution import AlgEvolution
import time
from src.backend.pdf_generator import PDFGenerator
import json
import pandas as pd

from IPython.display import display


def load_params(file_path):
    with open(file_path, "r") as file:
        params = json.load(file)
    return params



def main():
    tempo1 = time.time()

    data ={
        "CXPB": 0.9,
        "MUTPB": 0.05,
        "NGEN": 100,
        "POP_SIZE": 100,
        "IND_SIZE": 10,
        "evaluations": 0,
        "type": "Minimaze",
        "funcao objetivo": "Rastrigin",
        "num_genes": 5,
        "Variaveis decisao": [],
        "label": " "
    }


    #Setup
    params = load_params("/home/pedrov/Documentos/GitHub/Engenharia-Eletrica-UFF/Iniciação Cientifica - Eng Eletrica UFF/evolution_rce_master/src/db/parameters.json")
    data_visual = DataExploration()
    setup = Setup(params)
    alg = AlgEvolution(setup)
    pop_with_repopulation, logbook_with_repopulation, best_variables = alg.run(RCE=True,decision_variables=None, fitness_function= None)
    print("\nEvolução concluída  - 100%")




    # Salvar resultados
    all_df = data_visual.displayDataFrameInfo(alg.allIndividualValuesArray, "\n\nTodos Individuos Gerados")
    print("\n\n-->Conjunto Elite:", alg.pop_RCE)
    best_df = pd.DataFrame(alg.pop_RCE)
    display(best_df.sort_values(by = "Fitness" ,ascending=False))
    print(best_df.shape)

    print("\nResults RCE")
    alg.combinar_aleatoriamente()
    data_visual.plot_grafico_barras(setup.NGEN,best_df["Fitness"])


    

    
    # Visualização dos resultados
    print("\n\nVISUALIZANDO OS RESULTADOS")
    #TODO data_visual.displayDataFrameInfo(alg.best_individual_array, "Best 100 variables with repopulation")
    data_visual.visualize(
        logbook_with_repopulation, pop_with_repopulation, repopulation=True
    )
    data_visual.statistics_per_generation_df(logbook_with_repopulation)
    data_visual.plot_diversidade_genes(pop_with_repopulation)




    tempo2 = time.time()
    print(f"Total execution time: {round(tempo2-tempo1,2)} seconds")
main()
# Out:
# Método escolhido: Minimizar
#
# RCE being applied!  - Generation = 20
# TAMANHO ATUAL DE TODOS INDIVIDUOS 2000
#
#
# Melhor da geração: 1
# Name: Generations, dtype: int64
# /home/pedrov/.local/lib/python3.11/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
#    Generations  index                               Variaveis de Decisão  \
# 0            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#    Fitness  Media  Desvio Padrao  RCE
# 0      0.0    0.0            0.0   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(22) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(71) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(14) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(25) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(75) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(6) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 20, 'index': 6, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, -0.0059473267425125265, 1.295136825331217, 0.9349365969609202, -1.461257293151414, 0.03418890020485488, 0.01989559540062258], 'Fitness': 38.67273016479487, 'Media': 4.663042676124148, 'Desvio Padrao': 4.686621964768817, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 7) = 2 | random (80% de 100)= 80.0
#
# RCE being applied!  - Generation = 40
# TAMANHO ATUAL DE TODOS INDIVIDUOS 4000
#
#
# Melhor da geração: 1
# Name: Generations, dtype: int64
#    Generations  index                               Variaveis de Decisão  \
# 0            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#    Fitness  Media  Desvio Padrao  RCE
# 0      0.0    0.0            0.0   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(82) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(78) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 26, 'index': 78, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, -2.632590535307349, -0.0059473267425125265, 0.025913616385186078, 0.9349365969609202, 0.03623689244851025, 0.03418890020485488, 0.01989559540062258], 'Fitness': 26.181926542486497, 'Media': 3.330780028144565, 'Desvio Padrao': 3.5430868665804938, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 10) = 2 | random (80% de 100)= 80.0
#
# RCE being applied!  - Generation = 60
# TAMANHO ATUAL DE TODOS INDIVIDUOS 6000
#
#
# Melhor da geração: 1
# Name: Generations, dtype: int64
#    Generations  index                               Variaveis de Decisão  \
# 0            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#    Fitness  Media  Desvio Padrao  RCE
# 0      0.0    0.0            0.0   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(97) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(12) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 50, 'index': 12, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.3740837837546028, 1.6476898248028287, -0.0059473267425125265, 0.37388653426988566, 0.9349365969609202, 0.03623689244851025, 0.03418890020485488, 0.01989559540062258], 'Fitness': 55.344747349656785, 'Media': 3.7037785012446927, 'Desvio Padrao': 5.791825272943928, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 13) = 3 | random (80% de 100)= 80.0
#
# RCE being applied!  - Generation = 80
# TAMANHO ATUAL DE TODOS INDIVIDUOS 8000
#
#
# Melhor da geração: 1
# Name: Generations, dtype: int64
#    Generations  index                               Variaveis de Decisão  \
# 0            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#    Fitness  Media  Desvio Padrao  RCE
# 0      0.0    0.0            0.0   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(23) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 62, 'index': 23, 'Variaveis de Decisão': [1.4294229094664783, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, 1.379107376200559, 0.025913616385186078, 0.9349365969609202, 0.009187993634623106, 0.03418890020485488, 0.01989559540062258], 'Fitness': 42.715084421719396, 'Media': 4.0071219979647585, 'Desvio Padrao': 6.507967255631466, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 15) = 3 | random (80% de 100)= 80.0
#
# RCE being applied!  - Generation = 100
# TAMANHO ATUAL DE TODOS INDIVIDUOS 10000
#
#
# Melhor da geração: 1
# Name: Generations, dtype: int64
#    Generations  index                               Variaveis de Decisão  \
# 0            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#    Fitness  Media  Desvio Padrao  RCE
# 0      0.0    0.0            0.0   -
# Melhor da geração Adicionado no RCE!
#
# ==========================================================================================================
# 	 CRITÉRIO 1 RCE - 30% dos melhores fitness de cada geração
# ==========================================================================================================
#
#
# ==========================================================================================================
# 	 CRITÉRIO 2 - Comparar as variáveis de decisão de cada indivíduo e verificar se existem 3 diferentes.
# ==========================================================================================================
#
# Indivíduo Index(26) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(44) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(33) diferente adicionado ao conjunto elite:  O.O
# Indivíduo Index(79) diferente adicionado ao conjunto elite:  O.O
# Conjunto Elite atualizado!  ultimo inserido =  {'Generations': 95, 'index': 79, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, -0.0059473267425125265, 0.025913616385186078, -0.04475437913308607, 0.009187993634623106, 2.604714028627358, 0.01989559540062258], 'Fitness': 25.669114664563107, 'Media': 2.4218486096642238, 'Desvio Padrao': 5.449835359135273, 'RCE': ' - '}
#
# ==========================================================================================================
# 	 CRITERIO 3 - CONJUNTO ELITE (20%) com o restante aleatorio(80%)
# ==========================================================================================================
#
# Taxa Candidatos elite (20% de 20) = 4 | random (80% de 100)= 80.0
#
# Evolução concluída  - 100%
# =================================================================
#
#
# Todos Individuos Gerados
# =================================================================
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 1               1      1  [0.4677675096509071, 0.06380341646750709, 0.33...
# 2               1      2  [0.12681187828636442, 0.5490286216946143, 0.19...
# 3               1      3  [0.19196446658907684, 0.563504719536731, 0.714...
# 4               1      4  [0.07575641140761635, 0.9019672852155413, 0.86...
# ...           ...    ...                                                ...
# 9995          100     95  [0.008234307871545332, 0.009083483902797451, 0...
# 9996          100     96  [0.008234307871545332, 0.009083483902797451, 0...
# 9997          100     97  [0.008234307871545332, 0.009083483902797451, 0...
# 9998          100     98  [0.008234307871545332, 0.009083483902797451, 0...
# 9999          100     99  [0.008234307871545332, 0.009083483902797451, 0...
#
#       Fitness     Media  Desvio Padrao  RCE
# 0     0.00000  0.000000       0.000000   -
# 1     0.00000  0.000000       0.000000   -
# 2     0.00000  0.000000       0.000000   -
# 3     0.00000  0.000000       0.000000   -
# 4     0.00000  0.000000       0.000000   -
# ...       ...       ...            ...  ...
# 9995  1.20304  1.742227       3.079624   -
# 9996  1.20304  1.742227       3.079624   -
# 9997  1.20304  1.742227       3.079624   -
# 9998  1.20304  1.742227       3.079624   -
# 9999  1.20304  1.742227       3.079624   -
#
# [10000 rows x 7 columns]
# -->Conjunto Elite: [{'Generations': 1, 'index': 0, 'Variaveis de Decisão': [0.9599805774645643, 0.08994833324285312, 0.7829806588147793, 0.5637301534473631, 0.636994170884418, 0.2665661164815408, 0.7946568281860935, 0.35597542437424057, 0.49869683216949556, 0.028847765398309022], 'Fitness': 0.0, 'Media': 0.0, 'Desvio Padrao': 0.0, 'RCE': ' - '}, {'Generations': 4, 'index': 22, 'Variaveis de Decisão': [2.0185830961334386, 0.9019672852155413, 0.24330429054603964, 0.7226638777196088, 0.2722141758740311, -2.2368156211314134, 0.9349365969609202, 0.7873154554375736, 0.2863730250888018, 0.6377145260166283], 'Fitness': 93.53862419794066, 'Media': 68.04670387901676, 'Desvio Padrao': 14.043035975500265, 'RCE': ' - '}, {'Generations': 5, 'index': 71, 'Variaveis de Decisão': [0.8885509296745533, 1.3387224690481254, -0.7719012088140322, 0.039981266056545395, 0.856639800627719, 0.4613729783454571, 0.7188973320711872, 0.8864492437012063, 1.5426293624107124, 0.7157017982420986], 'Fitness': 104.56541293969174, 'Media': 56.61620029708066, 'Desvio Padrao': 13.030920968036398, 'RCE': ' - '}, {'Generations': 8, 'index': 14, 'Variaveis de Decisão': [0.07575641140761635, 0.9019672852155413, 0.817213851058742, 1.141024074986679, -0.14177993674109912, 0.025913616385186078, 2.5890311296423234, 0.9210093156630395, -0.7183122111751279, 0.8406248504488277], 'Fitness': 64.223307372516, 'Media': 29.620410535966926, 'Desvio Padrao': 9.08025018760112, 'RCE': ' - '}, {'Generations': 9, 'index': 25, 'Variaveis de Decisão': [0.07575641140761635, -0.23271467799896695, 0.817213851058742, 0.039981266056545395, 0.9666164887552459, 0.2665661164815408, 0.14791556898455327, 1.4349671648872655, 0.04298972020126235, 0.3985897450977488], 'Fitness': 73.0712384726156, 'Media': 22.66412951106068, 'Desvio Padrao': 8.041639237988564, 'RCE': ' - '}, {'Generations': 11, 'index': 75, 'Variaveis de Decisão': [-2.020936927048433, 1.1854089335540476, 0.021164906341444967, 0.039981266056545395, 0.931619966674628, 0.025913616385186078, 1.6146390763501202, 0.03623689244851025, 0.03418890020485488, 0.8905156727901352], 'Fitness': 37.62264523089159, 'Media': 13.691596753220496, 'Desvio Padrao': 3.9345922556128947, 'RCE': ' - '}, {'Generations': 20, 'index': 6, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, -0.0059473267425125265, 1.295136825331217, 0.9349365969609202, -1.461257293151414, 0.03418890020485488, 0.01989559540062258], 'Fitness': 38.67273016479487, 'Media': 4.663042676124148, 'Desvio Padrao': 4.686621964768817, 'RCE': ' - '}, {'Generations': 1, 'index': 0, 'Variaveis de Decisão': [0.9599805774645643, 0.08994833324285312, 0.7829806588147793, 0.5637301534473631, 0.636994170884418, 0.2665661164815408, 0.7946568281860935, 0.35597542437424057, 0.49869683216949556, 0.028847765398309022], 'Fitness': 0.0, 'Media': 0.0, 'Desvio Padrao': 0.0, 'RCE': ' - '}, {'Generations': 26, 'index': 82, 'Variaveis de Decisão': [-0.2407961479267956, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, -0.0059473267425125265, 0.025913616385186078, 0.9349365969609202, -0.823949024588451, 2.1794742239777363, 0.01989559540062258], 'Fitness': 28.385588012257873, 'Media': 3.330780028144565, 'Desvio Padrao': 3.5430868665804938, 'RCE': ' - '}, {'Generations': 26, 'index': 78, 'Variaveis de Decisão': [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, -2.632590535307349, -0.0059473267425125265, 0.025913616385186078, 0.9349365969609202, 0.03623689244851025, 0.03418890020485488, 0.01989559540062258], 'Fitness': 26.181926542486497, 'Media': 3.330780028144565, 'Desvio Padrao': 3.5430868665804938, 'RCE': ' - '}, {'Generations': 1, 'index': 0, 'Variaveis de Decisão': [0.9599805774645643, 0.08994833324285312, 0.7829806588147793, 0.5637301534473631, 0.636994170884418, 0.2665661164815408, 0.7946568281860935, 0.35597542437424057, 0.49869683216949556, 0.028847765398309022], 'Fitness': 0.0, 'Media': 0.0, 'Desvio Padrao': 0.0, 'RCE' ...
#     Generations  index                               Variaveis de Decisão  \
# 2             5     71  [0.8885509296745533, 1.3387224690481254, -0.77...
# 1             4     22  [2.0185830961334386, 0.9019672852155413, 0.243...
# 4             9     25  [0.07575641140761635, -0.23271467799896695, 0....
# 3             8     14  [0.07575641140761635, 0.9019672852155413, 0.81...
# 12           50     12  [0.008234307871545332, 0.009083483902797451, 0...
# 11           47     97  [-1.2709356036307047, 0.009083483902797451, 0....
# 16           84     26  [0.008234307871545332, 0.009083483902797451, 1...
# 14           62     23  [1.4294229094664783, 0.009083483902797451, 0.0...
# 6            20      6  [0.008234307871545332, 0.009083483902797451, 0...
# 5            11     75  [-2.020936927048433, 1.1854089335540476, 0.021...
# 17           84     44  [0.008234307871545332, 0.009083483902797451, 0...
# 8            26     82  [-0.2407961479267956, 0.009083483902797451, 0....
# 9            26     78  [0.008234307871545332, 0.009083483902797451, 0...
# 19           95     79  [0.008234307871545332, 0.009083483902797451, 0...
# 18           94     33  [1.0556638446451143, 1.2165037256111306, 0.021...
# 0             1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 15            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 13            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 7             1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 10            1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
#
#        Fitness      Media  Desvio Padrao  RCE
# 2   104.565413  56.616200      13.030921   -
# 1    93.538624  68.046704      14.043036   -
# 4    73.071238  22.664130       8.041639   -
# 3    64.223307  29.620411       9.080250   -
# 12   55.344747   3.703779       5.791825   -
# 11   46.356599   3.800975       5.536880   -
# 16   45.598236   2.689307       5.487831   -
# 14   42.715084   4.007122       6.507967   -
# 6    38.672730   4.663043       4.686622   -
# 5    37.622645  13.691597       3.934592   -
# 17   30.631891   2.689307       5.487831   -
# 8    28.385588   3.330780       3.543087   -
# 9    26.181927   3.330780       3.543087   -
# 19   25.669115   2.421849       5.449835   -
# 18   12.283807   1.614302       2.183111   -
# 0     0.000000   0.000000       0.000000   -
# 15    0.000000   0.000000       0.000000   -
# 13    0.000000   0.000000       0.000000   -
# 7     0.000000   0.000000       0.000000   -
# 10    0.000000   0.000000       0.000000   -
# (20, 7)
#
# Results RCE
#       Generations  index                               Variaveis de Decisão  \
# 0               1      0  [0.9599805774645643, 0.08994833324285312, 0.78...
# 1               4     22  [2.0185830961334386, 0.9019672852155413, 0.243...
# 2               5     71  [0.8885509296745533, 1.3387224690481254, -0.77...
# 3               8     14  [0.07575641140761635, 0.9019672852155413, 0.81...
# 4               9     25  [0.07575641140761635, -0.23271467799896695, 0....
# ...           ...    ...                                                ...
# 9940          100     40  [0.008234307871545332, 0.009083483902797451, 0...
# 9953          100     53  [0.008234307871545332, 0.009083483902797451, 0...
# 9974          100     74  [0.008234307871545332, 0.009083483902797451, 0...
# 9952          100     52  [0.008234307871545332, 0.009083483902797451, 0...
# 9949          100     49  [0.008234307871545332, 0.009083483902797451, 0...
#
#          Fitness      Media  Desvio Padrao  RCE
# 0       0.000000   0.000000       0.000000  SIM
# 1      93.538624  68.046704      14.043036  SIM
# 2     104.565413  56.616200      13.030921  SIM
# 3      64.223307  29.620411       9.080250  SIM
# 4      73.071238  22.664130       8.041639  SIM
# ...          ...        ...            ...  ...
# 9940    1.203040   1.742227       3.079624  NÃO
# 9953    1.203040   1.742227       3.079624  NÃO
# 9974    1.203040   1.742227       3.079624  NÃO
# 9952    1.203040   1.742227       3.079624  NÃO
# 9949    1.203040   1.742227       3.079624  NÃO
#
# [100 rows x 7 columns]
# VISUALIZANDO OS RESULTADOS
# =================================================================
# Soluções do problema
# =================================================================
#
# Best solution index =  0
#
# Best solution variables =
#  [0.008234307871545332, 0.009083483902797451, 0.021164906341444967, 0.03363277189324476, -0.0059473267425125265, 0.025913616385186078, -0.04475437913308607, 0.009187993634623106, 0.03418890020485488, 0.01989559540062258]
#
# Best solution fitness =  0.0
#
# Ótimo global da função Rastrigin =  1.4060621253975114e-06
#
# Solução ótima global =  [ 2.84868656e-05  1.68245378e-05  1.91585875e-05  2.06326140e-05
#  -4.26710249e-05 -7.31856211e-06  2.55654563e-05  3.13852902e-05
#   3.99102436e-05  9.70217591e-06]
#
# Porcentagem de proximidade da solução em relação ao ótimo global =  100.0 %
#
# Distância da solução em relação ao ótimo global = <built-in function abs>
# 100 100 100
# Plotando diversidade dos genes
# Total execution time: 4.91 seconds
